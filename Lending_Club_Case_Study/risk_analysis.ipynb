# %% [markdown]
# # Lending Club - Lending Risk Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# This note book details the analysis and the approach followed to investigate the driving factors behind the charged off loans.<br>
# The observations considered for the analysis are loan applications during the period 2007 - 2011. <br>
# The observations are the loans that are accepted by LC and eventually fully paid or charged off. <br>
# All the Inferences and Assumptions will follow the code instructions.The comments are embidded inside the code fragments.<br>
# <br>

# %%
#Import Required Libraries 

import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
import missingno as msno
import zipcodes as zc
import plotly as py
import plotly.graph_objs as go

# %%
# Set the session options
# %matplotlib inline
pd.options.display.max_columns = None
#pd.options.display.max_rows = None
warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Read file and let Python detect the variable types at the cost of memory, rather than guessing the dtypes.
loan=pd.read_csv(r'C:\Users\santo\Documents\PGDML\Course-1\Group_Project\loan.csv',low_memory=False)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# This section covers the Data Cleaning actions. The following is the high level Data cleaning approach -
#  - Remove all the columns that have no data.
#  - Remove all the rows that have no data.
#  - Remove all the columns that have single unique value.
#  - Remove all the columns that have NaNs in atleast 1/3rd of the total rows.
#  - Investigate each column and cleanse the data or delete as appropriate.

# %%
# Get some idea on the data size and sample data 
print(loan.shape)
loan.head(2)
# Out:
# (39717, 111)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000         4,975.00   36 months
# 1  1077430    1314167       2500         2500         2,500.00   60 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
# 1   15.27%        59.83     C        C4     Ryder   < 1 year           RENT
#
#    annual_inc verification_status issue_d  loan_status pymnt_plan  \
# 0   24,000.00            Verified  Dec-11   Fully Paid          n
# 1   30,000.00     Source Verified  Dec-11  Charged Off          n
#
#                                                  url  \
# 0  https://lendingclub.com/browse/loanDetail.acti...
# 1  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
# 1    Borrower added on 12/22/11 > I plan to use t...          car      bike
#
#   zip_code addr_state   dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    860xx         AZ 27.65            0           Jan-85               1
# 1    309xx         GA  1.00            0           Apr-99               5
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     nan                     nan         3        0
# 1                     nan                     nan         3        0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      13648     83.70%          9                   f       0.00
# 1       1687      9.40%          4                   f       0.00
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00     5,863.16         5,833.84         5,000.00
# 1           0.00     1,008.71         1,008.71           456.46
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         863.16                0.00        0.00                     0.00
# 1         435.17                0.00      117.08                     1.11
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0       Jan-15           171.62          NaN             May-16
# 1       Apr-13           119.66          NaN             Sep-13
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                        0.00                          nan            1
# 1                        0.00                          nan            1
#
#   application_type  annual_inc_joint  dti_joint  verification_status_joint  \
# 0       INDIVIDUAL               nan        nan                        nan
# 1       INDIVIDUAL               nan        nan                        nan
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# 0               0           nan          nan          nan         nan
# 1               0           nan          nan          nan         nan
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0          nan          nan                 nan           nan      nan
# 1          nan          nan                 nan           nan      nan
#
#    open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0          nan          nan         nan       nan               nan     nan
# 1          nan          nan         nan       nan               nan     nan
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0          nan           nan                   nan          nan
# 1          nan           nan                   nan          nan
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0             nan      nan                      0.00            0
# 1             nan      nan                      0.00            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0                 nan                   nan                    nan
# 1                 nan                   nan                    nan
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0             nan       nan                   nan                       nan
# 1             nan       nan                   nan                       nan
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    nan                             nan
# 1                    nan                             nan
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                    nan             nan              nan          nan
# 1                    nan             nan              nan          nan
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0        nan        nan            nan            nan                  nan
# 1        nan        nan            nan            nan                  nan
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0       nan               nan           nan                 nan
# 1       nan               nan           nan                 nan
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                 nan             nan               nan                  0.00
# 1                 nan             nan               nan                  0.00
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0       0.00              nan                nan             nan
# 1       0.00              nan                nan             nan
#
#    total_il_high_credit_limit
# 0                         nan
# 1                         nan

# %%
# Drop columns and Rows that have no Data.
loan_data=loan.dropna(axis='columns',how='all')
loan_data=loan_data.dropna(axis='rows',how='all')

#Drop columns that have same values
loan_unique=loan_data.nunique().sort_values()
unique_cols=loan_unique[loan_unique==1].index
loan_data.drop(columns=unique_cols,axis=1,inplace=True)

#Ignore columns that have atleast one-third of Nil values 
loan_data = loan_data.loc[:, (loan_data.isnull().sum(axis=0) <= len(loan_data)/3)]

#Now get the final size and remaining columns
print(loan_data.shape)
# Out:
# (39717, 45)

# %%
# Check the distribution of NaN across the columns
loan_data[loan_data.columns[loan_data.isnull().any()]].head(1)
# Out:
#   emp_title emp_length                                               desc  \
# 0       NaN  10+ years    Borrower added on 12/22/11 > I need to upgra...
#
#       title revol_util last_pymnt_d last_credit_pull_d  pub_rec_bankruptcies
# 0  Computer     83.70%       Jan-15             May-16                  0.00

# %%
msno.matrix(loan_data)

# %% [markdown]
# Now clean and treat each variable in the data set

# %%
loan_data.describe()
# Out:
#                 id    member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# count    39,717.00    39,717.00  39,717.00    39,717.00        39,717.00
# mean    683,131.91   850,463.56  11,219.44    10,947.71        10,397.45
# std     210,694.13   265,678.31   7,456.67     7,187.24         7,128.45
# min      54,734.00    70,699.00     500.00       500.00             0.00
# 25%     516,221.00   666,780.00   5,500.00     5,400.00         5,000.00
# 50%     665,665.00   850,812.00  10,000.00     9,600.00         8,975.00
# 75%     837,755.00 1,047,339.00  15,000.00    15,000.00        14,400.00
# max   1,077,501.00 1,314,167.00  35,000.00    35,000.00        35,000.00
#
#        installment   annual_inc       dti  delinq_2yrs  inq_last_6mths  \
# count    39,717.00    39,717.00 39,717.00    39,717.00       39,717.00
# mean        324.56    68,968.93     13.32         0.15            0.87
# std         208.87    63,793.77      6.68         0.49            1.07
# min          15.69     4,000.00      0.00         0.00            0.00
# 25%         167.02    40,404.00      8.17         0.00            0.00
# 50%         280.22    59,000.00     13.40         0.00            1.00
# 75%         430.78    82,300.00     18.60         0.00            1.00
# max       1,305.19 6,000,000.00     29.99        11.00            8.00
#
#        open_acc   pub_rec  revol_bal  total_acc  out_prncp  out_prncp_inv  \
# count 39,717.00 39,717.00  39,717.00  39,717.00  39,717.00      39,717.00
# mean       9.29      0.06  13,382.53      22.09      51.23          50.99
# std        4.40      0.24  15,885.02      11.40     375.17         373.82
# min        2.00      0.00       0.00       2.00       0.00           0.00
# 25%        6.00      0.00   3,703.00      13.00       0.00           0.00
# 50%        9.00      0.00   8,850.00      20.00       0.00           0.00
# 75%       12.00      0.00  17,058.00      29.00       0.00           0.00
# max       44.00      4.00 149,588.00      90.00   6,311.47       6,307.37
#
#        total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# count    39,717.00        39,717.00        39,717.00      39,717.00
# mean     12,153.60        11,567.15         9,793.35       2,263.66
# std       9,042.04         8,942.67         7,065.52       2,608.11
# min           0.00             0.00             0.00           0.00
# 25%       5,576.93         5,112.31         4,600.00         662.18
# 50%       9,899.64         9,287.15         8,000.00       1,348.91
# 75%      16,534.43        15,798.81        13,653.26       2,833.40
# max      58,563.68        58,563.68        35,000.02      23,563.68
#
#        total_rec_late_fee  recoveries  collection_recovery_fee  \
# count           39,717.00   39,717.00                39,717.00
# mean                 1.36       95.22                    12.41
# std                  7.29      688.74                   148.67
# min                  0.00        0.00                     0.00
# 25%                  0.00        0.00                     0.00
# 50%                  0.00        0.00                     0.00
# 75%                  0.00        0.00                     0.00
# max                180.20   29,623.35                 7,002.19
#
#        last_pymnt_amnt  pub_rec_bankruptcies
# count        39,717.00             39,020.00
# mean          2,678.83                  0.04
# std           4,447.14                  0.20
# min               0.00                  0.00
# 25%             218.68                  0.00
# 50%             546.14                  0.00
# 75%           3,293.16                  0.00
# max          36,115.20                  2.00

# %%
loan_data[loan_data['funded_amnt'] > loan_data['loan_amnt']]
# Out:
# Empty DataFrame
# Columns: [id, member_id, loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, open_acc, pub_rec, revol_bal, revol_util, total_acc, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, last_credit_pull_d, pub_rec_bankruptcies]
# Index: []

# %%
# Term - Check 'term' and remove the extra charecters 'Months'. Identify the unique values.
print('--- Term ----\n')
loan_data['term']=loan_data['term'].str.replace(' months','')
print(loan_data['term'].nunique())
print(loan_data['term'].unique())

# Loan Status - Convert loan_status to lower, remove any spaces and find unique values.
print('--- Loan Status ----\n')
loan_data['loan_status']=loan_data['loan_status'].str.strip().str.lower()
print(loan_data.loan_status.nunique())
print(loan_data.loan_status.unique())
print(loan_data.groupby(['loan_status'], as_index=False).size().reset_index(name='counts'))

# Employement Length - Replace the extraneous charecters in the employee length and impute the NaNs as 'Not Disclosed'
print('--- Employee Length ----\n')
loan_data['emp_length']=loan_data['emp_length'].str.strip().str.replace(' years','').str.replace('+','').str.replace('< 1','0').str.replace(' year','')
loan_data.emp_length.fillna(value='Not Disclosed',inplace=True)
print(loan_data.emp_length.unique())
print(loan_data.emp_length.describe())

# Investigate Annual income
print('--- Annual Income ----\n')
print(loan_data.annual_inc.median())

# Create a new derived column - log to the base 2 for annual income for analysis purpose
loan_data['annual_inc_log2']=np.log2(loan_data['annual_inc'])

# Issue Date - convert issue date to date time format
print('--- Issue Date ----\n')
loan_data['issue_date_dt']=pd.to_datetime(loan_data['issue_d'],format='%b-%y')
print(loan_data.issue_date_dt.describe())

# Dti - Identify the unique values
print('--- DTI ----\n')
print(loan_data.dti.nunique())

#delinq_2yrs - Number of 30+ months passed after delinquecy incidents in last 2 years.
print('--- delinq_2yrs ----\n')
print(loan_data.delinq_2yrs.nunique())
print(loan_data.delinq_2yrs.unique())
print(loan_data.groupby(by='delinq_2yrs')['id'].count())

#inq_last_6mth - Just check values
print('--- inq_last_6mth ----\n')
print(loan_data.inq_last_6mths.nunique())
print(loan_data.inq_last_6mths.unique())

#int_rate - apply the string cleaning and validate the nunique values
print('--- interest rate ----\n')
loan_data['int_rate_f']=loan_data['int_rate'].str.replace('%','').astype(float)
print(loan_data.int_rate_f.nunique())

#installemnt - Just check 
print('--- installment ----\n')
print(loan_data.installment.nunique())
print(loan_data.installment.describe())
print(loan_data.installment.median())

# pub_rec - Check the values
print('--- pub_rec ----\n')
print(loan_data.pub_rec.nunique())
print(loan_data.pub_rec.unique())

#pub_rec_bankruptcies - Impute 'Not known' for the bankruptcies record where the data is not available. 
print('--- pub_rec_bankruptcies ----\n')
print(loan_data.pub_rec_bankruptcies.unique())
loan_data.pub_rec_bankruptcies.fillna(value='Not Known',inplace=True)
print(loan_data.pub_rec_bankruptcies.unique())

# last_credit_pull_dt - Conver the format and validate the dates.
loan_data['last_credit_pull_dt']=pd.to_datetime(loan_data['last_credit_pull_d'],format='%b-%y')
print(loan_data['last_credit_pull_dt'].min())
print(loan_data['last_credit_pull_dt'].max())

# emp_title - Create a new derived column to categorize if the emp_title is disclosed or not
loan_data.emp_title.describe()
loan_data['emp_title_provided'] = np.where(np.logical_or(loan_data['emp_title'].isnull(), loan_data['emp_title'].str.strip() == ''), False, True)
loan_data['emp_title_provided']=loan_data['emp_title_provided'].apply(lambda x: 'Disclosed' if x is True else 'Not Disclosed')

# title - just check 
loan_data.title.describe()
loan_data.title.head(5)
# Out:
# --- Term ----
#
# 2
# [' 36' ' 60']
# --- Loan Status ----
#
# 3
# ['fully paid' 'charged off' 'current']
#    loan_status  counts
# 0  charged off    5627
# 1      current    1140
# 2   fully paid   32950
# --- Employee Length ----
#
# ['10' '0' '1' '3' '8' '9' '4' '5' '6' '2' '7' 'Not Disclosed']
# count     39717
# unique       12
# top          10
# freq       8879
# Name: emp_length, dtype: object
# --- Annual Income ----
#
# 59000.0
# --- Issue Date ----
#
# count                   39717
# unique                     55
# top       2011-12-01 00:00:00
# freq                     2260
# first     2007-06-01 00:00:00
# last      2011-12-01 00:00:00
# Name: issue_date_dt, dtype: object
# --- DTI ----
#
# 2868
# --- delinq_2yrs ----
#
# 11
# [ 0  2  3  1  4  6  5  8  7  9 11]
# delinq_2yrs
# 0     35405
# 1      3303
# 2       687
# 3       220
# 4        62
# 5        22
# 6        10
# 7         4
# 8         2
# 9         1
# 11        1
# Name: id, dtype: int64
# --- inq_last_6mth ----
#
# 9
# [1 5 2 0 3 4 6 7 8]
# --- interest rate ----
#
# 371
# --- installment ----
#
# 15383
# count   39,717.00
# mean       324.56
# std        208.87
# min         15.69
# 25%        167.02
# 50%        280.22
# 75%        430.78
# max      1,305.19
# Name: installment, dtype: float64
# 280.22
# --- pub_rec ----
#
# 5
# [0 1 2 3 4]
# --- pub_rec_bankruptcies ----
#
# [ 0.  1.  2. nan]
# [0.0 1.0 2.0 'Not Known']
# 2007-05-01 00:00:00
# 2016-05-01 00:00:00
# 0                Computer
# 1                    bike
# 2    real estate business
# 3                personel
# 4                Personal
# Name: title, dtype: object

# %% [markdown]
# ### Observation
# There is high variation of mean and median in annual income. So,clearly there are some outliers.

# %% [markdown]
# ### Home Owner ship

# %%
print(loan_data.home_ownership.unique())
# Out:
# ['RENT' 'OWN' 'MORTGAGE' 'OTHER' 'NONE']

# %%
# As per Data Dictionary, the values for howm ownership should be one of RENT' 'OWN' 'MORTGAGE' 'OTHER'.
# Convert them to lower case, stip out any spaces. 
# Identify how many are outside this designated category.
loan_data['home_ownership']=loan_data['home_ownership'].str.strip().str.lower()

# Values should be one of 'rent' 'own' 'mortgage' 'other' 
loan_data.groupby(by='home_ownership')['loan_amnt'].count()
loan_data[loan_data['home_ownership']=='none']
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv term  \
# 39318  231321     214993      10000        10000         1,228.06   36
# 39659  121568     121574       4000         4000         1,925.00   36
# 39660  121535     121373       2800         2800         1,625.00   36
#
#       int_rate  installment grade sub_grade emp_title emp_length  \
# 39318    7.75%       312.22     A        A3       ups          5
# 39659    9.64%       128.41     B        B4       NaN          0
# 39660    8.70%        88.65     B        B1       NaN          0
#
#       home_ownership  annual_inc verification_status issue_d loan_status  \
# 39318           none   22,200.00        Not Verified  Jan-08  fully paid
# 39659           none  100,000.00        Not Verified  Aug-07  fully paid
# 39660           none  120,000.00        Not Verified  Aug-07  fully paid
#
#                                                      url  \
# 39318  https://lendingclub.com/browse/loanDetail.acti...
# 39659  https://lendingclub.com/browse/loanDetail.acti...
# 39660  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                     desc             purpose  \
# 39318  I plan to pay off my credit cards, leaving me ...  debt_consolidation
# 39659  I took a high interest loan from Citibank in 2...               other
# 39660  The family is expanding in October and we are ...               other
#
#                                 title zip_code addr_state   dti  delinq_2yrs  \
# 39318                 Melinda Holster    233xx         VA  5.24            0
# 39659  Refinancing high interest loan    950xx         CA 15.00            0
# 39660                  Baby is coming    024xx         MA 15.00            0
#
#       earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# 39318           Apr-94               0         9        0       4767
# 39659           May-99               1         6        0       8155
# 39660           May-99               1         6        0       8155
#
#       revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  \
# 39318      8.70%         22       0.00           0.00    11,239.62
# 39659     14.90%          8       0.00           0.00     4,622.49
# 39660     14.90%          8       0.00           0.00     3,191.22
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 39318         1,380.00         9,999.99       1,239.63                0.00
# 39659         2,224.58         4,000.00         622.49                0.00
# 39660         1,852.05         2,800.00         391.22                0.00
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 39318        0.00                     0.00       Feb-11           313.59
# 39659        0.00                     0.00       Sep-10           129.76
# 39660        0.00                     0.00       Sep-10            89.80
#
#       last_credit_pull_d pub_rec_bankruptcies  annual_inc_log2 issue_date_dt  \
# 39318             Jan-11            Not Known            14.44    2008-01-01
# 39659             Aug-07            Not Known            16.61    2007-08-01
# 39660             Aug-07            Not Known            16.87    2007-08-01
#
#        int_rate_f last_credit_pull_dt emp_title_provided
# 39318        7.75          2011-01-01          Disclosed
# 39659        9.64          2007-08-01      Not Disclosed
# 39660        8.70          2007-08-01      Not Disclosed

# %%
# There are only 3 such observatiions. These observations doesn't cause any issue to the charged off loan univariate analysis.
# When we drop them from 'Fully paid' data, it is only a small percentage.

loan_data.drop(loan_data[loan_data.home_ownership == 'none'].index, inplace=True)
print(loan_data.home_ownership.unique())
# Out:
# ['rent' 'own' 'mortgage' 'other']

# %% [markdown]
# ### Verification status

# %%
print(loan_data.verification_status.nunique())
print(loan_data.verification_status.unique())
# Out:
# 3
# ['Verified' 'Source Verified' 'Not Verified']

# %%
# There are two categories here. Income verified or not. Source of income(employability) is verified or not. 
# We can derive new boolen column from income and source verification.

loan_data['source_verification'] = np.where(loan_data['verification_status'].str.strip() == 'Source Verified', True, False)
loan_data['income_verification'] = np.where(np.logical_or(loan_data['verification_status'].str.strip() == 'Verified', 
                                                    loan_data['verification_status'].str.strip() == 'Source Verified'), True, False)

print(loan_data.income_verification.nunique())
print(loan_data.income_verification.unique())
print(loan_data.source_verification.nunique())
print(loan_data.source_verification.unique())
# Out:
# 2
# [ True False]
# 2
# [False  True]

# %% [markdown]
# ### Purpose and Desc

# %%
loan_data['purpose']=loan_data['purpose'].str.strip().str.lower()
print(loan_data.purpose.describe())
print(loan_data.purpose.unique())
loan_data.grade.unique()
# Out:
# count                  39714
# unique                    14
# top       debt_consolidation
# freq                   18640
# Name: purpose, dtype: object
# ['credit_card' 'car' 'small_business' 'other' 'wedding'
#  'debt_consolidation' 'home_improvement' 'major_purchase' 'medical'
#  'moving' 'vacation' 'house' 'renewable_energy' 'educational']
# array(['B', 'C', 'A', 'E', 'F', 'D', 'G'], dtype=object)

# %%
# Genralise/Narrow down the loan purpose. For example, credit_card balance clearence is same as debit consolidation. 

purpose_map={'credit_card':'debt_consolidation',
            'car':'Auto',
             'small_business':'small_business',
             'other':'other',
             'wedding':'wedding',
             'debt_consolidation': 'debt_consolidation',
             'home_improvement':'home_improvement',
             'major_purchase':'major_purchase',
             'medical':'medical',
             'moving':'home_improvement',
             'vacation':'vacation',
             'house':'home_improvement',
             'renewable_energy':'home_improvement',
             'educational':'educational'
            }
loan_data['purpose_mapped']=loan_data['purpose'].map(purpose_map)

# %%
loan_data.groupby(by=['purpose_mapped'])['id'].count()
# Out:
# purpose_mapped
# Auto                   1549
# debt_consolidation    23770
# educational             325
# home_improvement       4043
# major_purchase         2187
# medical                 693
# other                  3991
# small_business         1828
# vacation                381
# wedding                 947
# Name: id, dtype: int64

# %%
# Impute 'Not Disclosed' in the 'Desc' column for NaNs
loan_data.desc.fillna(value='Not Disclosed',inplace=True)
print(loan_data.desc.describe())
# Out:
# count             39714
# unique            26525
# top       Not Disclosed
# freq              12940
# Name: desc, dtype: object

# %% [markdown]
# ### Observation
#  - From eye ball checks, it is evident that some of the loans are availed for debt consolidation.
#  - For example, with reason of wedding, loan was availed to clear off credit card balance.
# So process mapping will need to be done. Do a generic search for the work 'consolidate' and categorise the 'purpose'.
#  - We can only use the work 'pay off', but that will map some genuine observations. For this exercise we considered only 'consolidate'

# %%
# Apply the changes on 'purpose_mapped' as mentioned above.

a='consolidate'
temp_frame_non_dbtc=loan_data[loan_data['purpose_mapped']!='debt_consolidation']
temp_frame_dbtc=loan_data[loan_data['purpose_mapped']=='debt_consolidation']
bool_frame=temp_frame_non_dbtc['desc'].apply(lambda x:True if a in x else False)
temp_frame_non_dbtc_hits=temp_frame_non_dbtc[bool_frame]
temp_frame_non_dbtc_nohits=temp_frame_non_dbtc[~bool_frame]
temp_frame_non_dbtc_hits['purpose_mapped']='debt_consolidation'

loan_data = pd.concat([temp_frame_non_dbtc_hits,temp_frame_non_dbtc_nohits,temp_frame_dbtc],axis=0)

# %%
print(loan_data.groupby(by=['purpose_mapped'])['id'].count())
# Out:
# purpose_mapped
# Auto                   1538
# debt_consolidation    24124
# educational             314
# home_improvement       3995
# major_purchase         2145
# medical                 673
# other                  3804
# small_business         1819
# vacation                376
# wedding                 926
# Name: id, dtype: int64

# %% [markdown]
# ### Zip Code and Address State Cleaning

# %%
# Eye ball Check zip_code and address.
loan_data.groupby(by=['addr_state','zip_code'])['id'].count().reset_index()
# Out:
#     addr_state zip_code  id
# 0           AK    352xx   1
# 1           AK    363xx   1
# 2           AK    995xx  33
# 3           AK    996xx  13
# 4           AK    997xx  21
# 5           AK    998xx  10
# 6           AK    999xx   1
# 7           AL    350xx  57
# 8           AL    351xx  32
# 9           AL    352xx  61
# 10          AL    353xx   1
# 11          AL    354xx  21
# 12          AL    355xx  10
# 13          AL    356xx  32
# 14          AL    357xx  26
# 15          AL    358xx  18
# 16          AL    359xx  16
# 17          AL    360xx  23
# 18          AL    361xx  22
# 19          AL    362xx  11
# 20          AL    363xx  23
# 21          AL    364xx   5
# 22          AL    365xx  27
# 23          AL    366xx  36
# 24          AL    367xx   4
# 25          AL    368xx  26
# 26          AL    369xx   1
# 27          AR    711xx   1
# 28          AR    716xx  11
# 29          AR    717xx   9
# ..         ...      ...  ..
# 867         WV    252xx   1
# 868         WV    253xx  11
# 869         WV    254xx  29
# 870         WV    255xx  15
# 871         WV    256xx   5
# 872         WV    257xx   7
# 873         WV    258xx   8
# 874         WV    259xx   4
# 875         WV    260xx  19
# 876         WV    261xx  15
# 877         WV    262xx   4
# 878         WV    263xx   5
# 879         WV    264xx   6
# 880         WV    265xx  17
# 881         WV    266xx   1
# 882         WV    267xx   3
# 883         WV    268xx   6
# 884         WV    285xx   1
# 885         WY    282xx   1
# 886         WY    820xx  19
# 887         WY    822xx   4
# 888         WY    823xx   1
# 889         WY    824xx   7
# 890         WY    825xx   4
# 891         WY    826xx   8
# 892         WY    827xx   5
# 893         WY    828xx   7
# 894         WY    829xx  19
# 895         WY    830xx   7
# 896         WY    831xx   1
#
# [897 rows x 3 columns]

# %% [markdown]
# #### Assumption:
#  - We are assuming that the zip codes on the application are correct.
#  - State codes will be derived from python standard package using the zip codes.

# %%
# Clearly there is an issue. zip code of 352 and 363 belong to Alabama(AL) and not AK. 
# Set up code to extract correct state using zip-code.
loan_data['zip_code_str']=loan_data['zip_code'].str.replace('xx','')
a=loan_data['zip_code_str'].unique()
b=[]
c=[]
for i in a:  
    j=zc.similar_to(i)
    if len(j)==0:
        b.append('NIU')
        c.append('NOP')
    else:   
        b.append(j[0].get('state'))
        c.append(j[0].get('city'))
        
d={'zip_code_str':a,'state_code':b,'city_code':c}
temp_zip_code_frame=pd.DataFrame(data=d)
loan_data= loan_data.merge(temp_zip_code_frame, how = 'inner', on = ['zip_code_str'])

# %%
# Check zip_code and address.
print(loan_data.groupby(by=['state_code','zip_code_str'])['id'].count().reset_index())
# Out:
#     state_code zip_code_str  id
# 0           AE          090   1
# 1           AE          093   1
# 2           AE          094   2
# 3           AE          096   1
# 4           AK          995  33
# 5           AK          996  13
# 6           AK          997  21
# 7           AK          998  10
# 8           AK          999   1
# 9           AL          350  57
# 10          AL          351  32
# 11          AL          352  62
# 12          AL          354  21
# 13          AL          355  10
# 14          AL          356  32
# 15          AL          357  26
# 16          AL          358  18
# 17          AL          359  16
# 18          AL          360  23
# 19          AL          361  22
# 20          AL          362  11
# 21          AL          363  24
# 22          AL          364   5
# 23          AL          365  27
# 24          AL          366  36
# 25          AL          367   4
# 26          AL          368  26
# 27          AL          369   1
# 28          AP          963   2
# 29          AP          965   1
# ..         ...          ...  ..
# 793         WV          250   2
# 794         WV          251   8
# 795         WV          252   1
# 796         WV          253  11
# 797         WV          254  29
# 798         WV          255  15
# 799         WV          256   5
# 800         WV          257   7
# 801         WV          258   8
# 802         WV          259   4
# 803         WV          260  19
# 804         WV          261  15
# 805         WV          262   4
# 806         WV          263   5
# 807         WV          264   6
# 808         WV          265  17
# 809         WV          266   1
# 810         WV          267   3
# 811         WV          268   6
# 812         WY          820  19
# 813         WY          822   4
# 814         WY          823   1
# 815         WY          824   7
# 816         WY          825   4
# 817         WY          826   8
# 818         WY          827   6
# 819         WY          828   7
# 820         WY          829  19
# 821         WY          830   7
# 822         WY          831   1
#
# [823 rows x 3 columns]

# %% [markdown]
# The zip codes and the state codes now appear correct

# %% [markdown]
# ### Earliest_cr_line ( Date when the first credit was applied)

# %% [markdown]
# We can clean this column and calculate the Credit Age of the applicant. The credit Age will be the difference in the issue date <br>
# and date when the applicat first applied for the loan. Generally, the normal credit Age of the applicant is a good propect.<br>
# Too high credit age implies, the age of applicant is too high and so risky.<br>
# Too low credit age implies, there is uncertainity on the credit profile of the customer.

# %%
loan_data['earliest_cr_line_dt']=pd.to_datetime(loan_data['earliest_cr_line'],format='%b-%y')
print(loan_data['earliest_cr_line_dt'].min())
print(loan_data['earliest_cr_line_dt'].max())
# Out:
# 1969-02-01 00:00:00
# 2068-12-01 00:00:00

# %%
# Earliest credit line of 2068 doesn't make sense. This appears to be due to limitation in python. 
# Python datetime library can only read dates until 1968. 

loan_data['earliest_cr_line_dt_fine']=loan_data['earliest_cr_line_dt'].apply(lambda x :x.replace(year=x.year-100) if x.year > 2018 else x)
print(loan_data['earliest_cr_line_dt_fine'].min())
print(loan_data['earliest_cr_line_dt_fine'].max())
# Out:
# 1946-01-01 00:00:00
# 2008-11-01 00:00:00

# %%
# Take timedelta of issue_date_dt and earliest_cr_line_dt_fine to determin the 'credit Age/History of applicant'. 
# Calculate the credit History in terms of years

loan_data['time_delta']=loan_data['issue_date_dt']-loan_data['earliest_cr_line_dt_fine']
loan_data['time_delta_int']=loan_data['time_delta']/np.timedelta64(1, 'Y')
print(loan_data['time_delta_int'].min())
print(loan_data['time_delta_int'].max())
# Out:
# 2.998008172652416
# 65.41407421096942

# %% [markdown]
# ### Open_acc and total_acc

# %%
print(loan_data.open_acc.nunique())
print(loan_data.open_acc.unique())
# Out:
# 40
# [ 9  8 14 10  5 15  4  6  7 18 17 19 13 12 22 11  2 16 30 23  3 20 24 21
#  26 25 35 28 29 31 34 27 32 33 44 38 36 41 42 39]

# %%
print(loan_data.total_acc.nunique())
print(loan_data.total_acc.unique())
# Out:
# 82
# [21 16  9 39 24 26 35 15 36 12  8 17 29 37 45 23 27 19 40 14 20 42 10 13
#  54 38 18 25 22 31 33  7 28 49 30  3 34 56  6 50  4 77 53 41 11  5 59 32
#  52 46 47 48 44 60 51 43 79 62 63 57 61 67 90 58 55 70 65 71 78  2 64 76
#  81 68 69 87 75 66 73 72 74 80]

# %%
# Calculate the open account ratio
loan_data['open_acct_ratio']=loan_data['open_acc']/loan_data['total_acc']

# %%
# Do a sanity check on the ratio. It should be between 0 and 1.
loan_data[np.where(loan_data['open_acct_ratio'] > 1, True, False)]
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv term  \
# 35158  127213      85483       2000         2000         1,575.00   36
#
#       int_rate  installment grade sub_grade        emp_title emp_length  \
# 35158    7.12%        61.87     A        A1  U.S. Government         10
#
#       home_ownership  annual_inc verification_status issue_d loan_status  \
# 35158       mortgage  118,000.00        Not Verified  Sep-07  fully paid
#
#                                                      url              desc  \
# 35158  https://lendingclub.com/browse/loanDetail.acti...  consolidate debt
#
#                   purpose             title zip_code addr_state  dti  \
# 35158  debt_consolidation  consolidate debt    020xx         MA 0.43
#
#        delinq_2yrs earliest_cr_line  inq_last_6mths  open_acc  pub_rec  \
# 35158            0           Jun-91               0        14        0
#
#        revol_bal revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  \
# 35158       4709     18.50%          8       0.00           0.00     2,219.43
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 35158         1,747.80         2,000.00         219.43                0.00
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 35158        0.00                     0.00       Apr-10             3.06
#
#       last_credit_pull_d pub_rec_bankruptcies  annual_inc_log2 issue_date_dt  \
# 35158             Apr-10            Not Known            16.85    2007-09-01
#
#        int_rate_f last_credit_pull_dt emp_title_provided  source_verification  \
# 35158        7.12          2010-04-01          Disclosed                False
#
#        income_verification      purpose_mapped zip_code_str state_code  \
# 35158                False  debt_consolidation          020         MA
#
#       city_code earliest_cr_line_dt earliest_cr_line_dt_fine time_delta  \
# 35158    MILLIS          1991-06-01               1991-06-01  5936 days
#
#        time_delta_int  open_acct_ratio
# 35158           16.25             1.75

# %%
loan_data[loan_data['open_acct_ratio']<0]
# Out:
# Empty DataFrame
# Columns: [id, member_id, loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, open_acc, pub_rec, revol_bal, revol_util, total_acc, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, last_credit_pull_d, pub_rec_bankruptcies, annual_inc_log2, issue_date_dt, int_rate_f, last_credit_pull_dt, emp_title_provided, source_verification, income_verification, purpose_mapped, zip_code_str, state_code, city_code, earliest_cr_line_dt, earliest_cr_line_dt_fine, time_delta, time_delta_int, open_acct_ratio]
# Index: []

# %% [markdown]
# ### Observation:
# Looking at this observation, it appears that either total account or open account value was incorrectly keyed in. <br>
# There are two options -
#  -  to update the total_acc to '14' or
#  -  to delete the observation. (We can't give arbitrary open account)
# Dropping the observation makes sense as this is just 1 observation - a very small percentage of 'fully paid loans'.

# %%
loan_data.drop(loan_data[loan_data.id == 127213].index, inplace=True)

# %% [markdown]
# ### Revol_bal (Revolving Balance) and Revol_util (Revolving balance utilisation rate)

# %%
print(loan_data.revol_bal.nunique())
print(loan_data.revol_util.nunique())
# Out:
# 21711
# 1089

# %%
loan_data.revol_util=loan_data.revol_util.str.replace('%','').astype(float)

# %% [markdown]
# #### Note:
# There are some NaNs in the revolving utilization. See the percentage of the NaN values to the complete observations and <br>
# conclude if the observations with NaNs can be dropped.

# %%
print(loan_data[loan_data.revol_util.isna()].groupby(by='loan_status')['id'].count())
print('--------------')
print(loan_data[~loan_data.revol_util.isna()].groupby(by='loan_status')['id'].count())
# Out:
# loan_status
# charged off    16
# fully paid     34
# Name: id, dtype: int64
# --------------
# loan_status
# charged off     5611
# current         1140
# fully paid     32912
# Name: id, dtype: int64

# %%
## Drop these records, as the percentage is really small in each segment.
loan_data.dropna(subset=['revol_util'],inplace=True)

# %% [markdown]
# Analyse the values of each of the amount based columns. <br>
# These columns in general are the result of the loan status rather than the cause of the loan status <br>
# These columsn can be eventually dropped.

# %%
loan_data[loan_data['loan_status'] != 'current'][['out_prncp',
'out_prncp_inv',
'total_rec_prncp',
'total_rec_int',
'total_rec_late_fee',
'recoveries',
'collection_recovery_fee',
'total_pymnt',
'total_pymnt_inv',
'last_pymnt_d',
'last_pymnt_amnt']].describe()
# Out:
#        out_prncp  out_prncp_inv  total_rec_prncp  total_rec_int  \
# count  38,523.00      38,523.00        38,523.00      38,523.00
# mean        0.00           0.00         9,656.92       2,120.98
# std         0.00           0.00         7,009.52       2,390.52
# min         0.00           0.00             0.00           0.00
# 25%         0.00           0.00         4,500.00         644.86
# 50%         0.00           0.00         8,000.00       1,301.47
# 75%         0.00           0.00        13,200.00       2,673.27
# max         0.00           0.00        35,000.02      23,563.68
#
#        total_rec_late_fee  recoveries  collection_recovery_fee  total_pymnt  \
# count           38,523.00   38,523.00                38,523.00    38,523.00
# mean                 1.37       98.02                    12.75    11,877.29
# std                  7.32      699.03                   150.89     8,810.57
# min                  0.00        0.00                     0.00         0.00
# 25%                  0.00        0.00                     0.00     5,519.67
# 50%                  0.00        0.00                     0.00     9,686.87
# 75%                  0.00        0.00                     0.00    16,147.45
# max                180.20   29,623.35                 7,002.19    58,563.68
#
#        total_pymnt_inv  last_pymnt_amnt
# count        38,523.00        38,523.00
# mean         11,282.00         2,749.47
# std           8,701.26         4,496.89
# min               0.00             0.00
# 25%           5,031.53           217.78
# 50%           9,076.98           569.18
# 75%          15,341.95         3,451.66
# max          58,563.68        36,115.20

# %%
loan_data[loan_data['loan_status'] != 'current'][['out_prncp',
'out_prncp_inv',
'total_rec_prncp',
'total_rec_int',
'total_rec_late_fee',
'recoveries',
'collection_recovery_fee',
'total_pymnt',
'total_pymnt_inv',
'last_pymnt_d',
'last_pymnt_amnt']].nunique()
# Out:
# out_prncp                      1
# out_prncp_inv                  1
# total_rec_prncp             6828
# total_rec_int              33978
# total_rec_late_fee          1317
# recoveries                  4026
# collection_recovery_fee     2610
# total_pymnt                36660
# total_pymnt_inv            36335
# last_pymnt_d                 101
# last_pymnt_amnt            34386
# dtype: int64

# %% [markdown]
# ### Grade and Subgrade - Category of the loan assigned by Lending Club

# %% [markdown]
# There is no information on what basis the 'Grade' and 'Subgrade' are allocated to the observations. <br>
# Analysis will be done to understand if there are any correlated variables.

# %%
print(loan_data.grade.describe())
print(loan_data.sub_grade.describe())
# Out:
# count     39663
# unique        7
# top           B
# freq      12017
# Name: grade, dtype: object
# count     39663
# unique       35
# top          B3
# freq       2917
# Name: sub_grade, dtype: object

# %%
# Look at 'grade' and see how LC has assigned this value.
loan_data.grade.astype(str)
loan_data.sub_grade.astype(str)
loan_data.sort_values(by=['grade'])
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv term  \
# 0      1063270    1295780      10625        10625        10,625.00   36
# 13085   611832     784556      12000         7525         7,525.00   36
# 13087   606137     777558      12800         8575         8,575.00   36
# 13088   598187     767768      12000        12000        11,836.15   36
# 13090   585801     752621       4000         4000         4,000.00   36
# 13103   548765     707440       6000         6000         5,975.00   36
# 32086   355405     360126       6400         4500             0.00   36
# 13109   519899     672086       3000         3000         3,000.00   36
# 13111   504576     649617       5000         5000         4,825.00   36
# 13113   498915     640094       4800         4800         4,725.00   36
# 13119   470134     593400       6500         6500         6,425.00   36
# 32076   490678     626657      12000        12000        11,925.00   36
# 13083   623210     798709       5000         5000         4,900.00   36
# 13123   421428     495404       5000         5000         4,725.00   36
# 32072   518495     670214      16000        10275         9,556.69   60
# 32070   529073     684234      10000        10000         9,876.87   36
# 32069   550273     709310      12000        12000        12,000.00   36
# 32068   454838     563636      12000        12000        11,800.00   36
# 32067   571542     735176       6000         6000         6,000.00   36
# 13141  1051710    1283027       4000         4000         4,000.00   36
# 13143  1047659    1278758       5000         5000         5,000.00   36
# 32064   638399     817775      19000        19000        16,499.91   36
# 13150  1035024    1264634      13000        13000        13,000.00   36
# 13151  1030638    1260052       7000         7000         7,000.00   36
# 32060   674290     861853      12000        12000        12,000.00   36
# 13125   366128     377327       4000         4000         3,675.00   36
# 32052   816278    1023998      19200        19200        18,950.00   36
# 32104   644065     824208      15000        15000        15,000.00   36
# 32106   632676     810501       1000         1000           500.00   36
# 13010   386737     419208       6000         6000         5,650.00   36
# ...        ...        ...        ...          ...              ...  ...
# 32413   607296     779082      25000        25000        24,975.00   36
# 34780   763625     964264      12500        12500        12,500.00   36
# 4951   1025574    1254736      30000        30000        29,575.00   60
# 9510    419827     492729      12000        12000        11,840.11   36
# 25904   697926     889299      11500        11500        11,500.00   36
# 1186    579815     745420      25000        25000        24,975.00   36
# 19558   465172     583481       2500         2500         2,500.00   36
# 11157   689542     879845       4000         4000         4,000.00   60
# 11161   656295     839404      15000        15000        14,975.00   60
# 13482   635450     814031      15000        15000        15,000.00   60
# 15773   470224     593587      21600        21600        21,600.00   36
# 25376   706424     898629       7000         7000         7,000.00   60
# 38937   534252     690488      25000        25000        24,975.00   60
# 13513  1027164    1256374       5700         5700         5,700.00   60
# 12019   713857     907169      20675        20675        20,675.00   60
# 23746   695753     886871      20000        20000        19,950.00   60
# 29486   447676     548595       5000         5000         4,950.00   36
# 1362    420313     493506      25000        25000        11,100.00   36
# 22609   681074     870026      15000        15000        15,000.00   60
# 33659   616392     790355      25000        25000        24,675.00   60
# 18900   706606     854685      24000        24000        23,452.01   60
# 22611   669297     855767      32000        32000        31,684.90   60
# 19864   590333     758307      20000        20000        20,000.00   60
# 3864    622461     797752      15000        15000        15,000.00   60
# 34744   529529     684769       2800         2800         2,800.00   60
# 10376   747449     946378      16000        16000        16,000.00   60
# 26135  1058624    1290219      12375        12375        12,375.00   60
# 13558   362809     372424      24000        24000         8,213.72   36
# 22278   560292     721162      24000        24000        23,845.92   60
# 34311   607439     779253      25000        25000        24,875.00   36
#
#       int_rate  installment grade sub_grade  \
# 0        7.51%       330.56     A        A3
# 13085    5.79%       228.21     A        A2
# 13087    5.79%       260.06     A        A2
# 13088    7.51%       373.33     A        A4
# 13090    7.51%       124.45     A        A4
# 13103    7.14%       185.65     A        A3
# 32086    8.32%       141.68     A        A4
# 13109    7.51%        93.34     A        A4
# 13111    7.51%       155.55     A        A4
# 13113    7.51%       149.33     A        A4
# 13119    8.59%       205.47     A        A4
# 32076    7.88%       375.37     A        A5
# 13083    6.17%       152.50     A        A3
# 13123    9.63%       160.48     A        A5
# 32072    7.51%       205.94     A        A4
# 32070    7.88%       312.82     A        A5
# 32069    7.51%       373.33     A        A4
# 32068    7.51%       373.33     A        A4
# 32067    7.88%       187.69     A        A5
# 13141    6.03%       121.75     A        A1
# 13143    7.51%       155.56     A        A3
# 32064    6.91%       585.89     A        A5
# 13150    8.90%       412.80     A        A5
# 13151    7.51%       217.78     A        A3
# 32060    7.29%       372.12     A        A4
# 13125    9.32%       127.79     A        A4
# 32052    7.49%       597.16     A        A4
# 32104    5.79%       454.91     A        A2
# 32106    6.54%        30.67     A        A4
# 13010    9.63%       192.57     A        A5
# ...        ...          ...   ...       ...
# 32413   20.03%       929.48     G        G2
# 34780   22.11%       478.10     G        G1
# 4951    23.13%       847.96     G        G2
# 9510    18.84%       438.93     G        G1
# 25904   20.11%       428.03     G        G1
# 1186    20.16%       931.13     G        G1
# 19558   20.86%        94.02     G        G4
# 11157   21.22%       108.71     G        G4
# 11161   20.11%       398.33     G        G1
# 13482   20.03%       397.66     G        G2
# 15773   21.21%       816.14     G        G5
# 25376   20.11%       185.89     G        G1
# 38937   20.53%       669.75     G        G2
# 13513   23.52%       162.40     G        G3
# 12019   20.11%       549.03     G        G1
# 23746   20.85%       539.39     G        G3
# 29486   19.82%       185.37     G        G1
# 1362    18.84%       914.42     G        G1
# 22609   20.11%       398.33     G        G1
# 33659   20.77%       673.11     G        G4
# 18900   20.85%       647.26     G        G3
# 22611   20.85%       863.01     G        G3
# 19864   20.90%       539.95     G        G3
# 3864    19.66%       394.58     G        G1
# 34744   20.16%        74.44     G        G1
# 10376   23.59%       456.49     G        G5
# 26135   23.13%       349.79     G        G2
# 13558   18.72%       876.36     G        G3
# 22278   21.27%       652.94     G        G4
# 34311   19.66%       924.77     G        G1
#
#                                   emp_title emp_length home_ownership  \
# 0                        Dennis Alleman DMD          5       mortgage
# 13085         Mountain View School District         10       mortgage
# 13087               Futuro Infantil Hispano          0           rent
# 13088  Glendora Digestive Disease Institute          2       mortgage
# 13090                     Round Table Pizza          5       mortgage
# 13103                              TopOcean          0           rent
# 32086                    Westchester County          0            own
# 13109                    Marples Gears Inc.          7       mortgage
# 13111                         MOUNTAIN VIEW          2           rent
# 13113               Hansen Beverage Company          2       mortgage
# 13119                                   NaN          0       mortgage
# 32076                                   ibm         10       mortgage
# 13083                     TIME WARNER CABLE          7       mortgage
# 13123                                 LAUSD         10       mortgage
# 32072                        Ardsley School         10       mortgage
# 32070             Valiant Insurance Company          1           rent
# 32069                         Big Apple Pos          7            own
# 32068                     Skanska USA Civil          3       mortgage
# 32067                  city of white plains         10       mortgage
# 13141                        Relax The Back          2           rent
# 13143        Sotheby's International Realty          9       mortgage
# 32064         William Greene & Company, LLP          2       mortgage
# 13150             Automatic Data Processing          8           rent
# 13151               Pacific Engineers Group          6           rent
# 32060                       Timber Hill LLC          3           rent
# 13125                Hacienda La Puente USD          5          other
# 32052                  Hitachi America, Ltd         10       mortgage
# 32104                           Duke Energy         10       mortgage
# 32106                         AG industries         10       mortgage
# 13010                          Smith Barney          0           rent
# ...                                     ...        ...            ...
# 32413                      Life Techologies          4       mortgage
# 34780      Management Systems International          4           rent
# 4951                            Live Nation          3           rent
# 9510          Visual Statements Photography          8       mortgage
# 25904                       Planet Cellular          0            own
# 1186                                verizon         10       mortgage
# 19558                   JE merritts /Jacobs          4       mortgage
# 11157             Shetler Security Services          2           rent
# 11161                       City of Phoenix          6       mortgage
# 13482     Plaza Medical Center of Ft. Worth          3       mortgage
# 15773                        US Coast Guard          8           rent
# 25376                                Vonage          1           rent
# 38937        U.S. Federal Defender's Office         10       mortgage
# 13513                                   NaN          7       mortgage
# 12019                       DR Systems, Inc         10       mortgage
# 23746                             Razorfish          4           rent
# 29486                              HD Segur          2           rent
# 1362                            King County          2       mortgage
# 22609                   Atlantic Components          9           rent
# 33659                      CompuCom Systems         10       mortgage
# 18900                               VML Inc          6       mortgage
# 22611                  Best Bath Store, LLC          5           rent
# 19864             CITY AND COUNTY OF DENVER          5       mortgage
# 3864                      Family Healthcare          0       mortgage
# 34744            United States Marine Corps          3           rent
# 10376                  Lewis and Lewis Inc.          5            own
# 26135         University of Central Florida          5           rent
# 13558     Stafford Creek Corrections Center          8       mortgage
# 22278                national reprographics          8            own
# 34311                        Morgan Stanley          4           rent
#
#        annual_inc verification_status issue_d  loan_status  \
# 0       23,000.00        Not Verified  Dec-11   fully paid
# 13085   70,000.00     Source Verified  Nov-10   fully paid
# 13087   38,000.00            Verified  Nov-10   fully paid
# 13088   36,000.00        Not Verified  Oct-10   fully paid
# 13090   19,200.00     Source Verified  Sep-10   fully paid
# 13103   25,800.00        Not Verified  Jul-10   fully paid
# 32086   40,000.00        Not Verified  Sep-08   fully paid
# 13109  105,996.00     Source Verified  May-10   fully paid
# 13111   41,000.00        Not Verified  Apr-10   fully paid
# 13113   76,500.00        Not Verified  Apr-10   fully paid
# 13119   47,412.00        Not Verified  Dec-09   fully paid
# 32076  100,000.00        Not Verified  Mar-10   fully paid
# 13083   65,004.00            Verified  Dec-10   fully paid
# 13123  145,008.00            Verified  Jul-09   fully paid
# 32072   65,000.00        Not Verified  Jun-10  charged off
# 32070   73,000.00     Source Verified  Jun-10   fully paid
# 32069   60,000.00     Source Verified  Jul-10   fully paid
# 32068   58,000.00        Not Verified  Aug-10   fully paid
# 32067   90,000.00        Not Verified  Aug-10   fully paid
# 13141   54,000.00        Not Verified  Dec-11  charged off
# 13143   55,000.00            Verified  Dec-11   fully paid
# 32064  104,000.00     Source Verified  Dec-10   fully paid
# 13150   44,100.00        Not Verified  Nov-11   fully paid
# 13151   37,740.00     Source Verified  Nov-11   fully paid
# 32060   89,000.00        Not Verified  Feb-11   fully paid
# 13125   55,000.00        Not Verified  Dec-08   fully paid
# 32052   65,000.00        Not Verified  Jul-11   fully paid
# 32104  120,000.00            Verified  Jan-11   fully paid
# 32106   70,000.00            Verified  Dec-10   fully paid
# 13010   44,000.00            Verified  Mar-09   fully paid
# ...           ...                 ...     ...          ...
# 32413  120,000.00            Verified  Nov-10   fully paid
# 34780   50,000.00     Source Verified  May-11   fully paid
# 4951   102,500.00            Verified  Nov-11  charged off
# 9510    50,000.00            Verified  Jun-09   fully paid
# 25904   27,000.00     Source Verified  Mar-11   fully paid
# 1186    66,000.00     Source Verified  Sep-10   fully paid
# 19558   45,600.00        Not Verified  Dec-09  charged off
# 11157   24,000.00     Source Verified  Mar-11  charged off
# 11161   75,000.00            Verified  Jan-11   fully paid
# 13482   65,000.00            Verified  Dec-10   fully paid
# 15773   62,000.00            Verified  Dec-09   fully paid
# 25376   30,720.00     Source Verified  Mar-11  charged off
# 38937  150,000.00     Source Verified  Jun-10   fully paid
# 13513   95,000.00     Source Verified  Nov-11   fully paid
# 12019   98,000.00            Verified  Apr-11   fully paid
# 23746   85,000.00            Verified  Mar-11  charged off
# 29486   51,996.00        Not Verified  Dec-09   fully paid
# 1362   100,000.00            Verified  Jul-09   fully paid
# 22609   40,000.00     Source Verified  Feb-11   fully paid
# 33659   72,000.00            Verified  Nov-10   fully paid
# 18900  129,000.00            Verified  Mar-11   fully paid
# 22611   62,400.00            Verified  Feb-11   fully paid
# 19864   69,000.00            Verified  Oct-10  charged off
# 3864    92,000.00     Source Verified  Jan-11   fully paid
# 34744   20,400.00     Source Verified  Jun-10   fully paid
# 10376   35,088.00     Source Verified  May-11   fully paid
# 26135   40,000.00        Not Verified  Dec-11  charged off
# 13558   60,000.00        Not Verified  Nov-08  charged off
# 22278   80,000.00            Verified  Aug-10   fully paid
# 34311  100,000.00            Verified  Nov-10   fully paid
#
#                                                      url  \
# 0      https://lendingclub.com/browse/loanDetail.acti...
# 13085  https://lendingclub.com/browse/loanDetail.acti...
# 13087  https://lendingclub.com/browse/loanDetail.acti...
# 13088  https://lendingclub.com/browse/loanDetail.acti...
# 13090  https://lendingclub.com/browse/loanDetail.acti...
# 13103  https://lendingclub.com/browse/loanDetail.acti...
# 32086  https://lendingclub.com/browse/loanDetail.acti...
# 13109  https://lendingclub.com/browse/loanDetail.acti...
# 13111  https://lendingclub.com/browse/loanDetail.acti...
# 13113  https://lendingclub.com/browse/loanDetail.acti...
# 13119  https://lendingclub.com/browse/loanDetail.acti...
# 32076  https://lendingclub.com/browse/loanDetail.acti...
# 13083  https://lendingclub.com/browse/loanDetail.acti...
# 13123  https://lendingclub.com/browse/loanDetail.acti...
# 32072  https://lendingclub.com/browse/loanDetail.acti...
# 32070  https://lendingclub.com/browse/loanDetail.acti...
# 32069  https://lendingclub.com/browse/loanDetail.acti...
# 32068  https://lendingclub.com/browse/loanDetail.acti...
# 32067  https://lendingclub.com/browse/loanDetail.acti...
# 13141  https://lendingclub.com/browse/loanDetail.acti...
# 13143  https://lendingclub.com/browse/loanDetail.acti...
# 32064  https://lendingclub.com/browse/loanDetail.acti...
# 13150  https://lendingclub.com/browse/loanDetail.acti...
# 13151  https://lendingclub.com/browse/loanDetail.acti...
# 32060  https://lendingclub.com/browse/loanDetail.acti...
# 13125  https://lendingclub.com/browse/loanDetail.acti...
# 32052  https://lendingclub.com/browse/loanDetail.acti...
# 32104  https://lendingclub.com/browse/loanDetail.acti...
# 32106  https://lendingclub.com/browse/loanDetail.acti...
# 13010  https://lendingclub.com/browse/loanDetail.acti...
# ...                                                  ...
# 32413  https://lendingclub.com/browse/loanDetail.acti...
# 34780  https://lendingclub.com/browse/loanDetail.acti...
# 4951   https://lendingclub.com/browse/loanDetail.acti...
# 9510   https://lendingclub.com/browse/loanDetail.acti...
# 25904  https://lendingclub.com/browse/loanDetail.acti...
# 1186   https://lendingclub.com/browse/loanDetail.acti...
# 19558  https://lendingclub.com/browse/loanDetail.acti...
# 11157  https://lendingclub.com/browse/loanDetail.acti...
# 11161  https://lendingclub.com/browse/loanDetail.acti...
# 13482  https://lendingclub.com/browse/loanDetail.acti...
# 15773  https://lendingclub.com/browse/loanDetail.acti...
# 25376  https://lendingclub.com/browse/loanDetail.acti...
# 38937  https://lendingclub.com/browse/loanDetail.acti...
# 13513  https://lendingclub.com/browse/loanDetail.acti...
# 12019  https://lendingclub.com/browse/loanDetail.acti...
# 23746  https://lendingclub.com/browse/loanDetail.acti...
# 29486  https://lendingclub.com/browse/loanDetail.acti...
# 1362   https://lendingclub.com/browse/loanDetail.acti...
# 22609  https://lendingclub.com/browse/loanDetail.acti...
# 33659  https://lendingclub.com/browse/loanDetail.acti...
# 18900  https://lendingclub.com/browse/loanDetail.acti...
# 22611  https://lendingclub.com/browse/loanDetail.acti...
# 19864  https://lendingclub.com/browse/loanDetail.acti...
# 3864   https://lendingclub.com/browse/loanDetail.acti...
# 34744  https://lendingclub.com/browse/loanDetail.acti...
# 10376  https://lendingclub.com/browse/loanDetail.acti...
# 26135  https://lendingclub.com/browse/loanDetail.acti...
# 13558  https://lendingclub.com/browse/loanDetail.acti...
# 22278  https://lendingclub.com/browse/loanDetail.acti...
# 34311  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                     desc             purpose  \
# 0        Borrower added on 12/13/11 > I plan to conso...             medical
# 13085    Borrower added on 11/08/10 > We are using th...    home_improvement
# 13087    Borrower added on 10/28/10 > This loan will ...             wedding
# 13088                                      Not Disclosed               other
# 13090    Borrower added on 09/23/10 > My job is very ...      major_purchase
# 13103                                      Not Disclosed               other
# 32086  I will use this money to pay off the last of m...  debt_consolidation
# 13109                                      Not Disclosed               other
# 13111                                      Not Disclosed            vacation
# 13113                                      Not Disclosed               other
# 13119    Borrower added on 12/20/09 > I retired from ...             medical
# 32076    Borrower added on 03/05/10 > Plan to use fun...  debt_consolidation
# 13083                                      Not Disclosed    home_improvement
# 13123   This loan is requested to cover a family vaca...            vacation
# 32072    Borrower added on 05/22/10 > I been working ...  debt_consolidation
# 32070                                      Not Disclosed  debt_consolidation
# 32069                                      Not Disclosed  debt_consolidation
# 32068    Borrower added on 08/19/10 > I have a guaran...  debt_consolidation
# 32067                                      Not Disclosed         credit_card
# 13141    Borrower added on 12/05/11 > Hello Lenders, ...  debt_consolidation
# 13143                                      Not Disclosed  debt_consolidation
# 32064                                      Not Disclosed  debt_consolidation
# 13150    Borrower added on 11/21/11 > Credit Card Deb...         credit_card
# 13151                                      Not Disclosed         credit_card
# 32060                                      Not Disclosed         credit_card
# 13125  I am an elementary teacher and need to purchas...                 car
# 32052                                      Not Disclosed         credit_card
# 32104                                      Not Disclosed    home_improvement
# 32106                                      Not Disclosed            vacation
# 13010  I have several credit cards with low balances ...  debt_consolidation
# ...                                                  ...                 ...
# 32413    Borrower added on 11/02/10 > Personal Loan f...  debt_consolidation
# 34780    Borrower added on 05/22/11 > As many of you ...  debt_consolidation
# 4951                                       Not Disclosed  debt_consolidation
# 9510   Hello my name is Markesia Thomas-Akinbami.  I ...      small_business
# 25904    Borrower added on 03/10/11 > Hi! I am curren...  debt_consolidation
# 1186                                       Not Disclosed               house
# 19558                                      Not Disclosed               house
# 11157                                      Not Disclosed      small_business
# 11161    Borrower added on 01/18/11 > We are going to...    home_improvement
# 13482    Borrower added on 12/18/10 > These funds wil...  debt_consolidation
# 15773    Borrower added on 12/21/09 > This Loan is to...  debt_consolidation
# 25376    Borrower added on 03/18/11 > I apperciate th...             wedding
# 38937    Borrower added on 06/21/10 > My wife and I a...               house
# 13513                                      Not Disclosed      small_business
# 12019                                      Not Disclosed  debt_consolidation
# 23746    Borrower added on 03/07/11 > Still early in ...  debt_consolidation
# 29486   I am starting up an insurance agency in Manch...      small_business
# 1362       Looking to purchase an existing coffee shop.       small_business
# 22609                                      Not Disclosed  debt_consolidation
# 33659    Borrower added on 11/16/10 > Loan to update ...    home_improvement
# 18900  Extremely responsible borrower in a very stabl...    home_improvement
# 22611    Borrower added on 02/07/11 > Would like to u...  debt_consolidation
# 19864    Borrower added on 10/05/10 > First off, I wa...  debt_consolidation
# 3864                                       Not Disclosed  debt_consolidation
# 34744                                      Not Disclosed              moving
# 10376    Borrower added on 05/06/11 > I am planning o...      major_purchase
# 26135    Borrower added on 12/08/11 > I plan to use t...               other
# 13558   Would like to consolidate some credit card debt.  debt_consolidation
# 22278                                      Not Disclosed  debt_consolidation
# 34311                                      Not Disclosed  debt_consolidation
#
#                                           title zip_code addr_state   dti  \
# 0                                         Bills    970xx         OR 18.89
# 13085                                    Reroof    917xx         CA  8.55
# 13087  Loan to help start our future together..    917xx         CA 24.88
# 13088                      Pay off credit cards    917xx         CA  4.07
# 13090                           MOTORCYCLE LOAN    917xx         CA  1.63
# 13103                           Motorcycle Loan    917xx         CA  8.60
# 32086                        Debt Consolidation    105xx         NY 13.02
# 13109                                   loan 3k    917xx         CA  5.83
# 13111                    I AM HONEST & RELIABLE    917xx         CA  5.97
# 13113                                  Tax Loan    917xx         CA 16.20
# 13119                           a new beginning    917xx         CA  4.83
# 32076                                       REM    105xx         NY 11.83
# 13083                              LENDING TREE    917xx         CA 17.83
# 13123                                 Summer 09    917xx         CA 15.07
# 32072                                Jason loan    105xx         NY  9.30
# 32070                       Debit Consolidation    105xx         NY 17.03
# 32069                                    Steven    105xx         NY  8.30
# 32068                                      Hope    105xx         NY 15.35
# 32067                     credit card refinance    105xx         NY  6.76
# 13141                     Debt Free in 3 months    917xx         CA 17.53
# 13143                   Debt Consolidation Loan    917xx         CA 28.21
# 32064                       Debt Consolidation     105xx         NY 15.77
# 13150                          Credit Card Loan    917xx         CA 25.12
# 13151                     Credit Card Refinance    917xx         CA 16.72
# 32060  Financial Professional Credit Card Refi!    105xx         NY  7.67
# 13125      Teacher Needs Help to Purchase a Car    917xx         CA  6.76
# 32052                          Credit Card Loan    105xx         NY 10.82
# 32104                              Robby's Loan    280xx         NC  5.09
# 32106                               my vacation    280xx         NC 12.82
# 13010                  Consolidate Credit Cards    077xx         NJ  4.99
# ...                                         ...      ...        ...   ...
# 32413                             Personal Loan    142xx         NY 19.69
# 34780                        Debt Consolidation    222xx         VA 18.98
# 4951                    Debt Consolidation Loan    902xx         CA 22.57
# 9510                        IAAVS Business Loan    301xx         GA 12.60
# 25904                                Max's Loan    359xx         AL 10.22
# 1186                            to buy property    335xx         FL 13.07
# 19558                            singlemom loan    775xx         TX  0.53
# 11157                      Viking Entertainment    850xx         AZ  2.00
# 11161                         Home Improvements    850xx         AZ  4.58
# 13482                              debt pay off    760xx         TX 19.42
# 15773                     Financially Free Loan    100xx         NY 15.45
# 25376                              Wedding Loan    328xx         FL 12.70
# 38937                      Cowpet Unit Purchase    882xx         NM 14.86
# 13513                  BusinessCapital Infusion    985xx         WA  5.66
# 12019                                streamline    921xx         CA  9.04
# 23746                My 2011 Debt Consolidation    606xx         IL 20.89
# 29486                         Business Start-up    064xx         CT  5.53
# 1362                                Coffee Shop    980xx         WA  6.76
# 22609                   Debt Consolidation Loan    018xx         MA 13.08
# 33659                          Home Improvement    761xx         TX 19.12
# 18900  Home Improvement Loan:Siding Replacement    981xx         WA 16.80
# 22611       Debt Consolidation for organization    018xx         MA 13.04
# 19864                        DEBT CONSOLIDATION    800xx         CO 21.72
# 3864         graduate school debt consolidation    730xx         OK 21.34
# 34744                             Movement Loan    222xx         VA 19.82
# 10376                               Consolidate    829xx         WY 18.33
# 26135                                  Purchase    327xx         FL 20.88
# 13558                                  Personal    985xx         WA 19.80
# 22278                                   loan #1    110xx         NY 21.51
# 34311                                      Help    103xx         NY 12.73
#
#        delinq_2yrs earliest_cr_line  inq_last_6mths  open_acc  pub_rec  \
# 0                0           Feb-05               1         9        0
# 13085            0           Mar-81               0         7        0
# 13087            0           Dec-87               1        13        0
# 13088            0           Apr-93               0         8        0
# 13090            0           Mar-04               0         4        0
# 13103            0           Dec-01               0         9        0
# 32086            0           Jun-91               0         6        0
# 13109            0           Jan-97               0         8        0
# 13111            1           Jan-97               0         6        0
# 13113            0           Jul-95               0        12        0
# 13119            0           Jun-99               0         4        0
# 32076            0           Apr-95               0        15        0
# 13083            0           Sep-94               0        18        0
# 13123            0           Jan-85               0        11        0
# 32072            0           Apr-89               2         7        0
# 32070            0           Mar-96               3        14        0
# 32069            0           Oct-93               0        18        0
# 32068            0           Jul-96               3        10        0
# 32067            0           Aug-89               1        16        0
# 13141            2           Sep-87               2         8        0
# 13143            0           Aug-96               1        13        0
# 32064            0           Mar-95               0        20        0
# 13150            0           Apr-97               1        14        0
# 13151            0           Oct-04               0        10        0
# 32060            0           Jan-04               0         5        0
# 13125            0           Oct-99               0         8        0
# 32052            0           May-94               0        13        0
# 32104            0           Sep-78               1        18        0
# 32106            0           Jun-96               0         4        0
# 13010            0           Jul-97               0        18        0
# ...            ...              ...             ...       ...      ...
# 32413            1           Oct-00               0         6        0
# 34780            0           Feb-94               0        28        0
# 4951             0           Apr-95               0        14        0
# 9510             0           May-99               2        11        0
# 25904            0           Nov-06               2         4        0
# 1186             0           Aug-97               1         4        0
# 19558            0           Jun-04               3         3        0
# 11157            1           Dec-02               0         3        0
# 11161            1           Oct-01               0         4        0
# 13482            0           Nov-00               2        16        0
# 15773            0           Jun-01               1         3        0
# 25376            0           Nov-07               0         5        0
# 38937            0           Jul-94               0        11        0
# 13513            0           Dec-99               0         5        0
# 12019            2           Feb-94               0         5        0
# 23746            0           Mar-98               0        11        0
# 29486            0           Oct-05               1         8        0
# 1362             1           Jan-87               3        12        0
# 22609            2           May-04               0         5        0
# 33659            0           Feb-98               2        17        0
# 18900            1           Dec-97               0        15        0
# 22611            0           Apr-03               0         4        0
# 19864            0           Oct-00               0        12        0
# 3864             0           Jan-92               1        20        0
# 34744            0           Jan-07               0         3        0
# 10376            0           Dec-00               1         2        0
# 26135            0           Jan-96               0        27        0
# 13558            0           Nov-99               1        25        1
# 22278            0           May-84               1        34        0
# 34311            0           Sep-93               1        18        0
#
#        revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv  \
# 0           7114       43.40         21       0.00           0.00
# 13085      15102       33.00         32       0.00           0.00
# 13087       7448       26.60         23       0.00           0.00
# 13088       6110       17.60         21       0.00           0.00
# 13090        465        9.70          4       0.00           0.00
# 13103       2444       16.00         14       0.00           0.00
# 32086      12183       45.10         24       0.00           0.00
# 13109       4791       28.90         24       0.00           0.00
# 13111        499        4.80         10       0.00           0.00
# 13113      83440       77.80         28       0.00           0.00
# 13119       1369       27.40         15       0.00           0.00
# 32076      11876       44.40         29       0.00           0.00
# 13083      32944       12.50         43       0.00           0.00
# 13123      19654       77.40         20       0.00           0.00
# 32072       7083       22.30         14       0.00           0.00
# 32070      17979       38.90         20       0.00           0.00
# 32069      16426       19.60         36       0.00           0.00
# 32068       3201       60.50         37       0.00           0.00
# 32067      26090       29.20         43       0.00           0.00
# 13141       2529        8.20         10       0.00           0.00
# 13143      20060       59.90         33       0.00           0.00
# 32064      76487       31.20         38       0.00           0.00
# 13150      12842       66.50         29       0.00           0.00
# 13151       5723       18.30         12       0.00           0.00
# 32060       2323       32.40         14       0.00           0.00
# 13125       5287       18.40         22       0.00           0.00
# 32052      18259       18.70         28       0.00           0.00
# 32104       2783        5.80         46       0.00           0.00
# 32106       1893       49.80         14       0.00           0.00
# 13010      11741       14.60         30       0.00           0.00
# ...          ...         ...        ...        ...            ...
# 32413      66753       95.80         47       0.00           0.00
# 34780      12742       88.50         34       0.00           0.00
# 4951       35174       97.30         25       0.00           0.00
# 9510       11957       43.50         16       0.00           0.00
# 25904      11312       99.20         11       0.00           0.00
# 1186           0        0.00          9       0.00           0.00
# 19558       2106       91.60          3       0.00           0.00
# 11157        469       33.50          7       0.00           0.00
# 11161       3573       76.00         21       0.00           0.00
# 13482       7231       87.10         30       0.00           0.00
# 15773      10190       98.90         20       0.00           0.00
# 25376       1747       97.10          5       0.00           0.00
# 38937      17808       44.10         25       0.00           0.00
# 13513       9699       87.40          7       0.00           0.00
# 12019       1087       67.90         24       0.00           0.00
# 23746      21274       97.10         19       0.00           0.00
# 29486       1025       22.30          9       0.00           0.00
# 1362       38898       80.50         32       0.00           0.00
# 22609      10742       54.30         12       0.00           0.00
# 33659      12757       51.40         33       0.00           0.00
# 18900      25652       60.80         31       0.00           0.00
# 22611      27618       97.20         11       0.00           0.00
# 19864      13557       91.00         41       0.00           0.00
# 3864       27351       95.30         39       0.00           0.00
# 34744       1462       97.50          3       0.00           0.00
# 10376       3900       97.50         15       0.00           0.00
# 26135      13768       22.50         31       0.00           0.00
# 13558      23555       60.30         45       0.00           0.00
# 22278      21169       42.70         62       0.00           0.00
# 34311      36644       93.00         28       0.00           0.00
#
#        total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0        11,843.01        11,843.01        10,625.00       1,218.01
# 13085     8,215.62         8,215.62         7,525.00         690.62
# 13087     9,361.16         9,361.16         8,575.00         786.16
# 13088    12,775.41        12,591.25        12,000.00         775.41
# 13090     4,302.41         4,302.41         4,000.00         302.41
# 13103     6,667.27         6,639.49         6,000.00         667.27
# 32086     5,014.06             0.00         4,500.00         514.06
# 13109     3,360.06         3,360.06         3,000.00         360.06
# 13111     5,333.34         5,146.67         5,000.00         333.34
# 13113     5,375.93         5,291.93         4,800.00         575.93
# 13119     6,546.73         6,471.19         6,500.00          46.73
# 32076    13,514.25        13,429.79        12,000.00       1,514.25
# 13083     5,468.92         5,359.54         5,000.00         468.92
# 13123     5,793.20         5,474.57         5,000.00         778.20
# 32072     5,319.61         4,297.72         3,653.20       1,286.24
# 32070    11,261.90        11,116.54        10,000.00       1,261.90
# 32069    13,440.17        13,440.17        12,000.00       1,440.17
# 32068    12,721.64        12,509.60        12,000.00         721.64
# 32067     6,485.82         6,485.82         6,000.00         485.82
# 13141     3,643.22         3,643.22         3,163.54         365.65
# 13143     5,548.33         5,548.33         5,000.00         548.33
# 32064    20,412.40        17,457.94        19,000.00       1,412.40
# 13150    14,860.46        14,860.46        13,000.00       1,860.46
# 13151     7,839.91         7,839.91         7,000.00         839.91
# 32060    13,396.25        13,396.25        12,000.00       1,396.25
# 13125     4,058.83         3,729.07         4,000.00          58.83
# 32052    20,074.29        19,812.91        19,200.00         874.29
# 32104    16,376.99        16,376.99        15,000.00       1,376.99
# 32106     1,104.06           552.03         1,000.00         104.06
# 13010     6,932.33         6,527.94         5,999.99         932.34
# ...            ...              ...              ...            ...
# 32413    33,476.58        33,443.11        25,000.00       8,476.58
# 34780    17,250.29        17,250.29        12,500.00       4,726.38
# 4951      7,810.50         7,699.64         1,687.56       4,490.06
# 9510     15,801.01        15,523.03        12,000.00       3,801.01
# 25904    13,679.00        13,679.00        11,500.00       2,179.00
# 1186     33,524.20        33,490.67        25,000.00       8,524.20
# 19558     2,672.00         2,672.00         1,803.31         828.69
# 11157       927.85           927.85           278.09         476.72
# 11161    17,467.04        17,437.93        15,000.00       2,467.04
# 13482    23,040.47        23,040.47        15,000.00       8,040.47
# 15773    29,421.54        29,421.54        21,600.00       7,782.29
# 25376       314.48           314.48             0.00           0.00
# 38937    29,071.81        29,042.74        25,000.00       4,071.81
# 13513     9,593.29         9,593.29         5,700.00       3,893.29
# 12019    28,886.83        28,886.83        20,675.00       8,211.83
# 23746     5,391.17         5,377.72         2,063.50       3,307.88
# 29486     5,242.70         5,190.27         5,000.00         242.70
# 1362     29,426.07        13,065.17        25,000.00       4,426.07
# 22609    20,262.18        20,262.18        15,000.00       5,262.18
# 33659    40,385.93        39,860.91        25,000.00      15,385.93
# 18900    36,819.23        35,446.00        24,000.00      12,819.23
# 22611    44,455.80        43,592.80        32,000.01      12,455.79
# 19864    15,348.57        15,348.57         6,513.17       8,063.11
# 3864     23,218.18        23,218.18        15,000.00       8,218.18
# 34744     4,465.62         4,465.62         2,800.00       1,665.62
# 10376    20,664.88        20,664.88        16,000.00       4,664.88
# 26135     8,530.26         8,530.26         2,444.99       4,602.60
# 13558     2,627.79         1,001.16         1,528.74       1,099.05
# 22278    39,175.46        38,767.46        24,000.00      15,175.46
# 34311    32,309.84        32,148.29        25,000.00       7,265.00
#
#        total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  \
# 0                    0.00        0.00                     0.00       Jun-14
# 13085                0.00        0.00                     0.00       Dec-13
# 13087                0.00        0.00                     0.00       Oct-13
# 13088                0.00        0.00                     0.00       Nov-11
# 13090                0.00        0.00                     0.00       Jun-12
# 13103                0.00        0.00                     0.00       Mar-13
# 32086                0.00        0.00                     0.00       Aug-10
# 13109                0.00        0.00                     0.00       Jun-13
# 13111                0.00        0.00                     0.00       Jul-11
# 13113                0.00        0.00                     0.00       Apr-13
# 13119                0.00        0.00                     0.00       Feb-10
# 32076                0.00        0.00                     0.00       Mar-13
# 13083                0.00        0.00                     0.00       May-13
# 13123               15.00        0.00                     0.00       Aug-12
# 32072                0.00      380.17                     3.90       Jun-12
# 32070                0.00        0.00                     0.00       Jun-13
# 32069                0.00        0.00                     0.00       Aug-13
# 32068                0.00        0.00                     0.00       Aug-11
# 32067                0.00        0.00                     0.00       Dec-11
# 13141                0.00      114.03                     1.14       May-14
# 13143                0.00        0.00                     0.00       Feb-14
# 32064                0.00        0.00                     0.00       May-12
# 13150                0.00        0.00                     0.00       Dec-14
# 13151                0.00        0.00                     0.00       Dec-14
# 32060                0.00        0.00                     0.00       Mar-14
# 13125                0.00        0.00                     0.00       Feb-09
# 32052                0.00        0.00                     0.00       Apr-12
# 32104                0.00        0.00                     0.00       Jan-14
# 32106                0.00        0.00                     0.00       Jan-14
# 13010                0.00        0.00                     0.00       Apr-12
# ...                   ...         ...                      ...          ...
# 32413                0.00        0.00                     0.00       Nov-13
# 34780               23.91        0.00                     0.00       Jul-14
# 4951                 0.00    1,632.88                    15.44       Mar-13
# 9510                 0.00        0.00                     0.00       Jul-12
# 25904                0.00        0.00                     0.00       Apr-12
# 1186                 0.00        0.00                     0.00       Oct-13
# 19558                0.00       40.00                     0.60       May-12
# 11157                0.00      173.04                     1.65       Oct-11
# 11161                0.00        0.00                     0.00       Feb-12
# 13482                0.00        0.00                     0.00       Sep-14
# 15773               39.26        0.00                     0.00       Feb-13
# 25376                0.00      314.48                     2.95          NaN
# 38937                0.00        0.00                     0.00       May-12
# 13513                0.00        0.00                     0.00       Feb-16
# 12019                0.00        0.00                     0.00       Sep-13
# 23746                0.00       19.79                     0.00       Feb-12
# 29486                0.00        0.00                     0.00       Mar-10
# 1362                 0.00        0.00                     0.00       Sep-10
# 22609                0.00        0.00                     0.00       Mar-13
# 33659                0.00        0.00                     0.00       Dec-15
# 18900                0.00        0.00                     0.00       Nov-14
# 22611                0.00        0.00                     0.00       Apr-13
# 19864                0.00      772.29                     7.90       Feb-13
# 3864                 0.00        0.00                     0.00       Jan-15
# 34744                0.00        0.00                     0.00       Jun-15
# 10376                0.00        0.00                     0.00       Sep-12
# 26135                0.00    1,482.67                    23.01       Jan-14
# 13558                0.00        0.00                     0.00       Feb-09
# 22278                0.00        0.00                     0.00       Sep-15
# 34311               44.84        0.00                     0.00       Dec-12
#
#        last_pymnt_amnt last_credit_pull_d pub_rec_bankruptcies  \
# 0             2,594.01             Oct-15                 0.00
# 13085           248.37             Nov-13                 0.00
# 13087           545.81             Oct-13                 0.00
# 13088         8,684.18             Jul-13                 0.00
# 13090           443.61             Jul-15                 0.00
# ...
# 19864            16.07    2010-10-01       20.90          2013-06-01
# 3864             16.49    2011-01-01       19.66          2015-01-01
# 34744            14.32    2010-06-01       20.16          2015-06-01
# 10376            15.10    2011-05-01       23.59          2012-10-01
# 26135            15.29    2011-12-01       23.13          2014-02-01
# 13558            15.87    2008-11-01       18.72          2016-05-01
# 22278            16.29    2010-08-01       21.27          2015-08-01
# 34311            16.61    2010-11-01       19.66          2012-11-01
#
#       emp_title_provided  source_verification  income_verification  \
# 0              Disclosed                False                False
# 13085          Disclosed                 True                 True
# 13087          Disclosed                False                 True
# 13088          Disclosed                False                False
# 13090          Disclosed                 True                 True
# 13103          Disclosed                False                False
# 32086          Disclosed                False                False
# 13109          Disclosed                 True                 True
# 13111          Disclosed                False                False
# 13113          Disclosed                False                False
# 13119      Not Disclosed                False                False
# 32076          Disclosed                False                False
# 13083          Disclosed                False                 True
# 13123          Disclosed                False                 True
# 32072          Disclosed                False                False
# 32070          Disclosed                 True                 True
# 32069          Disclosed                 True                 True
# 32068          Disclosed                False                False
# 32067          Disclosed                False                False
# 13141          Disclosed                False                False
# 13143          Disclosed                False                 True
# 32064          Disclosed                 True                 True
# 13150          Disclosed                False                False
# 13151          Disclosed                 True                 True
# 32060          Disclosed                False                False
# 13125          Disclosed                False                False
# 32052          Disclosed                False                False
# 32104          Disclosed                False                 True
# 32106          Disclosed                False                 True
# 13010          Disclosed                False                 True
# ...                  ...                  ...                  ...
# 32413          Disclosed                False                 True
# 34780          Disclosed                 True                 True
# 4951           Disclosed                False                 True
# 9510           Disclosed                False                 True
# 25904          Disclosed                 True                 True
# 1186           Disclosed                 True                 True
# 19558          Disclosed                False                False
# 11157          Disclosed                 True                 True
# 11161          Disclosed                False                 True
# 13482          Disclosed                False                 True
# 15773          Disclosed                False                 True
# 25376          Disclosed                 True                 True
# 38937          Disclosed                 True                 True
# 13513      Not Disclosed                 True                 True
# 12019          Disclosed                False                 True
# 23746          Disclosed                False                 True
# 29486          Disclosed                False                False
# 1362           Disclosed                False                 True
# 22609          Disclosed                 True                 True
# 33659          Disclosed                False                 True
# 18900          Disclosed                False                 True
# 22611          Disclosed                False                 True
# 19864          Disclosed                False                 True
# 3864           Disclosed                 True                 True
# 34744          Disclosed                 True                 True
# 10376          Disclosed                 True                 True
# 26135          Disclosed                False                False
# 13558          Disclosed                False                False
# 22278          Disclosed                False                 True
# 34311          Disclosed                False                 True
#
#            purpose_mapped zip_code_str state_code          city_code  \
# 0      debt_consolidation          970         OR           ANTELOPE
# 13085    home_improvement          917         CA   CITY OF INDUSTRY
# 13087             wedding          917         CA   CITY OF INDUSTRY
# 13088               other          917         CA   CITY OF INDUSTRY
# 13090      major_purchase          917         CA   CITY OF INDUSTRY
# 13103               other          917         CA   CITY OF INDUSTRY
# 32086  debt_consolidation          105         NY            AMAWALK
# 13109               other          917         CA   CITY OF INDUSTRY
# 13111            vacation          917         CA   CITY OF INDUSTRY
# 13113               other          917         CA   CITY OF INDUSTRY
# 13119             medical          917         CA   CITY OF INDUSTRY
# 32076  debt_consolidation          105         NY            AMAWALK
# 13083    home_improvement          917         CA   CITY OF INDUSTRY
# 13123            vacation          917         CA   CITY OF INDUSTRY
# 32072  debt_consolidation          105         NY            AMAWALK
# 32070  debt_consolidation          105         NY            AMAWALK
# 32069  debt_consolidation          105         NY            AMAWALK
# 32068  debt_consolidation          105         NY            AMAWALK
# 32067  debt_consolidation          105         NY            AMAWALK
# 13141  debt_consolidation          917         CA   CITY OF INDUSTRY
# 13143  debt_consolidation          917         CA   CITY OF INDUSTRY
# 32064  debt_consolidation          105         NY            AMAWALK
# 13150  debt_consolidation          917         CA   CITY OF INDUSTRY
# 13151  debt_consolidation          917         CA   CITY OF INDUSTRY
# 32060  debt_consolidation          105         NY            AMAWALK
# 13125                Auto          917         CA   CITY OF INDUSTRY
# 32052  debt_consolidation          105         NY            AMAWALK
# 32104    home_improvement          280         NC          ALBEMARLE
# 32106            vacation          280         NC          ALBEMARLE
# 13010  debt_consolidation          077         NJ           ADELPHIA
# ...                   ...          ...        ...                ...
# 32413  debt_consolidation          142         NY            BUFFALO
# 34780  debt_consolidation          222         VA          ARLINGTON
# 4951   debt_consolidation          902         CA       BELL GARDENS
# 9510       small_business          301         GA            ACWORTH
# 25904  debt_consolidation          359         AL        ALBERTVILLE
# 1186     home_improvement          335         FL               BALM
# 19558    home_improvement          775         TX              ALVIN
# 11157      small_business          850         AZ            PHOENIX
# 11161    home_improvement          850         AZ            PHOENIX
# 13482  debt_consolidation          760         TX              ALEDO
# 15773  debt_consolidation          100         NY           NEW YORK
# 25376             wedding          328         FL            ORLANDO
# 38937    home_improvement          882         NM            ARTESIA
# 13513      small_business          985         WA           ABERDEEN
# 12019  debt_consolidation          921         CA          SAN DIEGO
# 23746  debt_consolidation          606         IL            CHICAGO
# 29486      small_business          064         CT            ANSONIA
# 1362       small_business          980         WA             AUBURN
# 22609  debt_consolidation          018         MA            ANDOVER
# 33659    home_improvement          761         TX         FORT WORTH
# 18900    home_improvement          981         WA            SEATTLE
# 22611  debt_consolidation          018         MA            ANDOVER
# 19864  debt_consolidation          800         CO             ARVADA
# 3864   debt_consolidation          730         OK             ALBERT
# 34744    home_improvement          222         VA          ARLINGTON
# 10376      major_purchase          829         WY          BONDURANT
# 26135               other          327         FL  ALTAMONTE SPRINGS
# 13558  debt_consolidation          985         WA           ABERDEEN
# 22278  debt_consolidation          110         NY             INWOOD
# 34311  debt_consolidation          103         NY      STATEN ISLAND
#
#       earliest_cr_line_dt earliest_cr_line_dt_fine time_delta  time_delta_int  \
# 0              2005-02-01               2005-02-01  2494 days            6.83
# 13085          1981-03-01               1981-03-01 10837 days           29.67
# 13087          1987-12-01               1987-12-01  8371 days           22.92
# 13088          1993-04-01               1993-04-01  6392 days           17.50
# 13090          2004-03-01               2004-03-01  2375 days            6.50
# 13103          2001-12-01               2001-12-01  3134 days            8.58
# 32086          1991-06-01               1991-06-01  6302 days           17.25
# 13109          1997-01-01               1997-01-01  4868 days           13.33
# 13111          1997-01-01               1997-01-01  4838 days           13.25
# 13113          1995-07-01               1995-07-01  5388 days           14.75
# 13119          1999-06-01               1999-06-01  3836 days           10.50
# 32076          1995-04-01               1995-04-01  5448 days           14.92
# 13083          1994-09-01               1994-09-01  5935 days           16.25
# 13123          1985-01-01               1985-01-01  8947 days           24.50
# 32072          1989-04-01               1989-04-01  7731 days           21.17
# 32070          1996-03-01               1996-03-01  5205 days           14.25
# 32069          1993-10-01               1993-10-01  6117 days           16.75
# 32068          1996-07-01               1996-07-01  5144 days           14.08
# 32067          1989-08-01               1989-08-01  7670 days           21.00
# 13141          1987-09-01               1987-09-01  8857 days           24.25
# 13143          1996-08-01               1996-08-01  5600 days           15.33
# 32064          1995-03-01               1995-03-01  5754 days           15.75
# 13150          1997-04-01               1997-04-01  5327 days           14.58
# 13151          2004-10-01               2004-10-01  2587 days            7.08
# 32060          2004-01-01               2004-01-01  2588 days            7.09
# 13125          1999-10-01               1999-10-01  3349 days            9.17
# 32052          1994-05-01               1994-05-01  6270 days           17.17
# 32104          1978-09-01               1978-09-01 11810 days           32.33
# 32106          1996-06-01               1996-06-01  5296 days           14.50
# 13010          1997-07-01               1997-07-01  4261 days           11.67
# ...                   ...                      ...        ...             ...
# 32413          2000-10-01               2000-10-01  3683 days           10.08
# 34780          1994-02-01               1994-02-01  6298 days           17.24
# 4951           1995-04-01               1995-04-01  6058 days           16.59
# 9510           1999-05-01               1999-05-01  3684 days           10.09
# 25904          2006-11-01               2006-11-01  1581 days            4.33
# 1186           1997-08-01               1997-08-01  4779 days           13.08
# 19558          2004-06-01               2004-06-01  2009 days            5.50
# 11157          2002-12-01               2002-12-01  3012 days            8.25
# 11161          2001-10-01               2001-10-01  3379 days            9.25
# 13482          2000-11-01               2000-11-01  3682 days           10.08
# 15773          2001-06-01               2001-06-01  3105 days            8.50
# 25376          2007-11-01               2007-11-01  1216 days            3.33
# 38937          1994-07-01               1994-07-01  5814 days           15.92
# 13513          1999-12-01               1999-12-01  4353 days           11.92
# 12019          1994-02-01               1994-02-01  6268 days           17.16
# 23746          1998-03-01               1998-03-01  4748 days           13.00
# 29486          2005-10-01               2005-10-01  1522 days            4.17
# 1362           1987-01-01               1987-01-01  8217 days           22.50
# 22609          2004-05-01               2004-05-01  2467 days            6.75
# 33659          1998-02-01               1998-02-01  4656 days           12.75
# 18900          1997-12-01               1997-12-01  4838 days           13.25
# 22611          2003-04-01               2003-04-01  2863 days            7.84
# 19864          2000-10-01               2000-10-01  3652 days           10.00
# 3864           1992-01-01               1992-01-01  6940 days           19.00
# 34744          2007-01-01               2007-01-01  1247 days            3.41
# 10376          2000-12-01               2000-12-01  3803 days           10.41
# 26135          1996-01-01               1996-01-01  5813 days           15.92
# 13558          1999-11-01               1999-11-01  3288 days            9.00
# 22278          1984-05-01               1984-05-01  9588 days           26.25
# 34311          1993-09-01               1993-09-01  6270 days           17.17
#
#        open_acct_ratio
# 0                 0.43
# 13085             0.22
# 13087             0.57
# 13088             0.38
# 13090             1.00
# 13103             0.64
# 32086             0.25
# 13109             0.33
# 13111             0.60
# 13113             0.43
# 13119             0.27
# 32076             0.52
# 13083             0.42
# 13123             0.55
# 32072             0.50
# 32070             0.70
# 32069             0.50
# 32068             0.27
# 32067             0.37
# 13141             0.80
# 13143             0.39
# 32064             0.53
# 13150             0.48
# 13151             0.83
# 32060             0.36
# 13125             0.36
# 32052             0.46
# 32104             0.39
# 32106             0.29
# 13010             0.60
# ...                ...
# 32413             0.13
# 34780             0.82
# 4951              0.56
# 9510              0.69
# 25904             0.36
# 1186              0.44
# 19558             1.00
# 11157             0.43
# 11161             0.19
# 13482             0.53
# 15773             0.15
# 25376             1.00
# 38937             0.44
# 13513             0.71
# 12019             0.21
# 23746             0.58
# 29486             0.89
# 1362              0.38
# 22609             0.42
# 33659             0.52
# 18900             0.48
# 22611             0.36
# 19864             0.29
# 3864              0.51
# 34744             1.00
# 10376             0.13
# 26135             0.87
# 13558             0.56
# 22278             0.55
# 34311             0.64
#
# [39663 rows x 61 columns]

# %%
# From the above, looks like, there is some relation between 'grade and 'sub-grade'. Sort both of them.
loan_data.sort_values(by=['grade','sub_grade'])
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv term  \
# 53      606714     778331      10000        10000        10,000.00   36
# 83     1051899    1283411      12000        12000        12,000.00   36
# 146     979294    1202375      16000        16000        16,000.00   36
# 175     647439     828331      12000        12000        11,975.00   36
# 219    1001871    1227675       3000         3000         3,000.00   36
# 223     973417    1195415      15000        15000        14,925.00   36
# 254     709846     902520       3500         3500         3,425.00   36
# 274     670625     857335       5050         5050         5,050.00   36
# 421     888973    1105417      10000        10000         9,975.00   36
# 434     853345    1065506       9600         9600         9,550.00   36
# 439     844985    1056112       3500         3500         3,500.00   36
# 478     734123     930598       2000         2000         2,000.00   36
# 656    1011131    1238189       8000         8000         8,000.00   36
# 657     985644    1209357      10000        10000         9,975.00   36
# 778     741734     939717       4200         4200         4,200.00   36
# 789     627209     803704       8000         8000         8,000.00   36
# 947    1064926    1298978       5000         5000         5,000.00   36
# 966     846040    1057361       5000         5000         5,000.00   36
# 979     777508     980007       3000         3000         2,975.00   36
# 981     765193     966039       3000         3000         3,000.00   36
# 983     749594     948842       3600         3600         3,575.00   36
# 992     686474     876291       4500         4500         4,450.00   36
# 994     660519     844795       2500         2500         2,500.00   36
# 998     633176     811147       5600         5600         5,600.00   36
# 1017    522376     675686       1000         1000         1,000.00   36
# 1063    828798    1037857       2400         2400         2,400.00   36
# 1161    889036    1105554       6425         6425         6,425.00   36
# 1229    765968     966927       7000         7000         6,975.00   36
# 1287   1001709    1227918      10000        10000        10,000.00   36
# 1304    766354     967351      12000        12000        12,000.00   36
# ...        ...        ...        ...          ...              ...  ...
# 3225    685886     875609      30000        30000        29,906.36   60
# 3243    580346     746061      20000        20000        19,975.00   60
# 5112    831341    1040557      14500        14500        14,475.00   60
# 5587    561454     722563      22000        22000        22,000.00   60
# 6258    698937     890431      20000        20000        19,975.00   60
# 7317    217100     217064      24625        13875         9,225.00   36
# 7937    460090     573933      13000        13000        12,892.28   36
# 9858    465596     584314      20000        20000        19,975.00   36
# 10376   747449     946378      16000        16000        16,000.00   60
# 11234   763262     963821      35000        29850        29,825.00   60
# 13790   730637     926621       4700         4700         4,700.00   60
# 13800   665644     851048       6200         6200         6,200.00   36
# 15773   470224     593587      21600        21600        21,600.00   36
# 16383   976164    1198310      21250        21250        21,225.00   60
# 17717   735036     931644      19125        19125        19,092.12   60
# 18805   429126     508289      16750        16750        12,973.51   36
# 19404  1045885    1276311      25000        25000        25,000.00   60
# 20391   842083    1052700      13650        13650        13,650.00   60
# 22208   598736     768472      25000        15200        14,775.00   60
# 22978   584264     750735      25000        25000        22,128.67   36
# 25018  1047612    1278509      24250        24250        24,225.00   60
# 25260   609795     782125      24000        24000        23,800.00   60
# 25932   610015     782385      10000        10000         9,950.00   36
# 29694   456812     567538      19750        19750        19,675.00   36
# 30870   730424     926381      35000        32000        31,975.00   60
# 31311   634290     812581       8800         8800         8,800.00   60
# 33493   660798     845134      25000        25000        24,822.14   60
# 34259   421847     496051      16750        16750        13,750.00   36
# 36306   779386     982068      25000        19100        19,100.00   60
# 39291   710167     902889      14600        14600        14,550.00   60
#
#       int_rate  installment grade sub_grade  \
# 53       5.42%       301.60     A        A1
# 83       6.03%       365.23     A        A1
# 146      6.03%       486.97     A        A1
# 175      5.42%       361.92     A        A1
# 219      6.03%        91.31     A        A1
# 223      6.03%       456.54     A        A1
# 254      5.42%       105.56     A        A1
# 274      5.42%       152.31     A        A1
# 421      6.03%       304.36     A        A1
# 434      5.42%       289.54     A        A1
# 439      5.42%       105.56     A        A1
# 478      5.42%        60.32     A        A1
# 656      6.03%       243.49     A        A1
# 657      6.03%       304.36     A        A1
# 778      5.42%       126.68     A        A1
# 789      5.42%       241.28     A        A1
# 947      6.03%       152.18     A        A1
# 966      5.42%       150.80     A        A1
# 979      5.42%        90.48     A        A1
# 981      5.42%        90.48     A        A1
# 983      5.42%       108.58     A        A1
# 992      5.42%       135.72     A        A1
# 994      5.42%        75.40     A        A1
# 998      5.42%       168.90     A        A1
# 1017     6.39%        30.60     A        A1
# 1063     5.42%        72.39     A        A1
# 1161     6.03%       195.55     A        A1
# 1229     5.42%       211.12     A        A1
# 1287     6.03%       304.36     A        A1
# 1304     5.42%       361.92     A        A1
# ...        ...          ...   ...       ...
# 3225    21.59%       821.59     G        G5
# 3243    21.64%       548.30     G        G5
# 5112    23.59%       413.70     G        G5
# 5587    21.64%       603.13     G        G5
# 6258    21.59%       547.73     G        G5
# 7317    18.36%       504.13     G        G5
# 7937    21.21%       491.20     G        G5
# 9858    21.21%       755.69     G        G5
# 10376   23.59%       456.49     G        G5
# 11234   23.59%       851.64     G        G5
# 13790   21.59%       128.72     G        G5
# 13800   21.59%       235.47     G        G5
# 15773   21.21%       816.14     G        G5
# 16383   24.11%       612.68     G        G5
# 17717   21.59%       523.77     G        G5
# 18805   20.11%       623.40     G        G5
# 19404   24.11%       720.80     G        G5
# 20391   23.59%       389.45     G        G5
# 22208   21.14%       412.41     G        G5
# 22978   21.64%       950.12     G        G5
# 25018   24.11%       699.18     G        G5
# 25260   21.14%       651.18     G        G5
# 25932   21.14%       377.47     G        G5
# 29694   21.21%       746.24     G        G5
# 30870   21.59%       876.37     G        G5
# 31311   21.14%       238.77     G        G5
# 33493   21.59%       684.66     G        G5
# 34259   20.11%       623.40     G        G5
# 36306   24.59%       556.03     G        G5
# 39291   21.59%       399.85     G        G5
#
#                                      emp_title     emp_length home_ownership  \
# 53                                         NaN             10       mortgage
# 83                 Research Triangle Institute              0           rent
# 146                                        NaN              7       mortgage
# 175                        smithfield housing              10       mortgage
# 219                        McCormick Ambulance              2           rent
# 223                 Cedars Sinai Health System              0       mortgage
# 254    Art Institute of California - Hollywood              0           rent
# 274                  A.L.Ayala Roofing co.inc.             10       mortgage
# 421                    The Walt Disney Company              1           rent
# 434            Willis Insurance Services of CA              6       mortgage
# 439                              Mechanix Wear              1           rent
# 478                           Agfa Corporation             10       mortgage
# 656                              Corporate Air             10       mortgage
# 657                           SkyWest Airlines              0       mortgage
# 778                            Cordish Company              2           rent
# 789               Second Empire Furniture Inc.             10       mortgage
# 947           m.s.c.z. inc earthwize recycling              9       mortgage
# 966            Loma Linda VA Healthcare System             10       mortgage
# 979                                        NaN  Not Disclosed       mortgage
# 981                                        NaN  Not Disclosed       mortgage
# 983                       Town of Apple Valley              9       mortgage
# 992                            dalton trucking              7       mortgage
# 994                           C.A.N. Transport              2       mortgage
# 998                            General Atomics              3       mortgage
# 1017                     Victor Valley College             10       mortgage
# 1063                           Kenco Logistics              2       mortgage
# 1161                Bell Shoals Baptist Church              5       mortgage
# 1229                           Hewlett Packard             10       mortgage
# 1287                                       NaN  Not Disclosed           rent
# 1304                          Bloom Consulting              1       mortgage
# ...                                        ...            ...            ...
# 3225                                       DTI              9       mortgage
# 3243            Schlumberger Oilfield Services              7       mortgage
# 5112             Ahmad, Zavitsanos & Anaipakos              3       mortgage
# 5587     Winters Joint Unified School District              0           rent
# 6258                        Morrow-Meadows Co.              2           rent
# 7317                             E & J Hauling             10           rent
# 7937                                       NaN              0           rent
# 9858                                       NaN              0       mortgage
# 10376                     Lewis and Lewis Inc.              5            own
# 11234       Maricopa Integrated Health Systems              4           rent
# 13790              Loganville Foot  and  Ankle              2           rent
# 13800                        City of Covington             10       mortgage
# 15773                           US Coast Guard              8           rent
# 16383         Kingsbrook Jewish Medical Center              5           rent
# 17717                          ARK Systems Inc              4           rent
# 18805                             Premier Pets              0           rent
# 19404                   Ashbrook Simon-Hartley              4       mortgage
# 20391                                    Medco              3           rent
# 22208                              MillerCoors             10       mortgage
# 22978                  Housing Investments Inc             10           rent
# 25018               Medical Management Options              1       mortgage
# 25260                           General Motors             10           rent
# 25932                             milton ruben              2       mortgage
# 29694                       FW MADIGAN cOMPANY              0       mortgage
# 30870                           Borgess Health              0           rent
# 31311                         Sherwin Williams             10           rent
# 33493                                      NaN              4            own
# 34259                                   SIDDSO             10           rent
# 36306                                      NaN              6       mortgage
# 39291                    ROBINS AIR FORCE BASE             10       mortgage
#
#        annual_inc verification_status issue_d  loan_status  \
# 53     100,000.00        Not Verified  Nov-10   fully paid
# 83      75,000.00     Source Verified  Dec-11   fully paid
# 146    180,000.00     Source Verified  Oct-11   fully paid
# 175     66,912.00        Not Verified  Jan-11   fully paid
# 219     30,000.00        Not Verified  Oct-11   fully paid
# 223    100,000.00            Verified  Oct-11   fully paid
# 254     42,000.00     Source Verified  Apr-11   fully paid
# 274     69,900.00     Source Verified  Feb-11   fully paid
# 421    121,200.00            Verified  Sep-11   fully paid
# 434     49,000.00     Source Verified  Aug-11   fully paid
# 439     70,000.00     Source Verified  Aug-11   fully paid
# 478     54,000.00            Verified  Apr-11   fully paid
# 656     50,000.00            Verified  Nov-11   fully paid
# 657     63,132.00     Source Verified  Oct-11   fully paid
# 778     62,000.00        Not Verified  May-11   fully paid
# 789     31,000.00        Not Verified  Dec-10   fully paid
# 947     30,000.00        Not Verified  Dec-11   fully paid
# 966    118,000.00            Verified  Aug-11   fully paid
# 979     16,908.00            Verified  Jun-11   fully paid
# 981     68,400.00        Not Verified  May-11   fully paid
# 983     60,000.00        Not Verified  May-11   fully paid
# 992     48,000.00        Not Verified  Mar-11   fully paid
# 994     39,996.00     Source Verified  Jan-11   fully paid
# 998     39,000.00        Not Verified  Dec-10   fully paid
# 1017    70,885.00     Source Verified  May-10   fully paid
# 1063    27,840.00        Not Verified  Aug-11   fully paid
# 1161   113,000.00        Not Verified  Sep-11   fully paid
# 1229    72,000.00     Source Verified  May-11   fully paid
# 1287    60,000.00     Source Verified  Nov-11   fully paid
# 1304   100,000.00        Not Verified  Jun-11   fully paid
# ...           ...                 ...     ...          ...
# 3225   150,000.00            Verified  Mar-11   fully paid
# 3243    75,000.00            Verified  Sep-10   fully paid
# 5112   150,000.00            Verified  Aug-11   fully paid
# 5587   105,000.00            Verified  Aug-10  charged off
# 6258    80,000.00        Not Verified  Mar-11   fully paid
# 7317    84,000.00        Not Verified  Jan-08   fully paid
# 7937   156,000.00        Not Verified  Nov-09   fully paid
# 9858    76,800.00        Not Verified  Dec-09   fully paid
# 10376   35,088.00     Source Verified  May-11   fully paid
# 11234  100,000.00            Verified  Jun-11   fully paid
# 13790   24,996.00     Source Verified  Apr-11   fully paid
# 13800   62,900.00        Not Verified  Feb-11  charged off
# 15773   62,000.00            Verified  Dec-09   fully paid
# 16383   80,000.00            Verified  Oct-11  charged off
# 17717   53,004.00        Not Verified  Apr-11   fully paid
# 18805   60,000.00            Verified  Jul-09  charged off
# 19404  145,000.00            Verified  Dec-11   fully paid
# 20391   40,000.00        Not Verified  Aug-11  charged off
# 22208  110,000.00            Verified  Oct-10   fully paid
# 22978  203,000.00            Verified  Sep-10  charged off
# 25018  108,000.00            Verified  Dec-11   fully paid
# 25260  110,000.00            Verified  Nov-10   fully paid
# 25932  108,000.00     Source Verified  Nov-10  charged off
# 29694  125,000.00        Not Verified  Nov-09  charged off
# 30870  360,000.00            Verified  Apr-11   fully paid
# 31311   62,400.00            Verified  Dec-10   fully paid
# 33493   60,000.00     Source Verified  Feb-11  charged off
# 34259   94,000.00            Verified  Jul-09  charged off
# 36306  200,000.00            Verified  Jun-11      current
# 39291  185,000.00        Not Verified  Mar-11   fully paid
#
#                                                      url  \
# 53     https://lendingclub.com/browse/loanDetail.acti...
# 83     https://lendingclub.com/browse/loanDetail.acti...
# 146    https://lendingclub.com/browse/loanDetail.acti...
# 175    https://lendingclub.com/browse/loanDetail.acti...
# 219    https://lendingclub.com/browse/loanDetail.acti...
# 223    https://lendingclub.com/browse/loanDetail.acti...
# 254    https://lendingclub.com/browse/loanDetail.acti...
# 274    https://lendingclub.com/browse/loanDetail.acti...
# 421    https://lendingclub.com/browse/loanDetail.acti...
# 434    https://lendingclub.com/browse/loanDetail.acti...
# 439    https://lendingclub.com/browse/loanDetail.acti...
# 478    https://lendingclub.com/browse/loanDetail.acti...
# 656    https://lendingclub.com/browse/loanDetail.acti...
# 657    https://lendingclub.com/browse/loanDetail.acti...
# 778    https://lendingclub.com/browse/loanDetail.acti...
# 789    https://lendingclub.com/browse/loanDetail.acti...
# 947    https://lendingclub.com/browse/loanDetail.acti...
# 966    https://lendingclub.com/browse/loanDetail.acti...
# 979    https://lendingclub.com/browse/loanDetail.acti...
# 981    https://lendingclub.com/browse/loanDetail.acti...
# 983    https://lendingclub.com/browse/loanDetail.acti...
# 992    https://lendingclub.com/browse/loanDetail.acti...
# 994    https://lendingclub.com/browse/loanDetail.acti...
# 998    https://lendingclub.com/browse/loanDetail.acti...
# 1017   https://lendingclub.com/browse/loanDetail.acti...
# 1063   https://lendingclub.com/browse/loanDetail.acti...
# 1161   https://lendingclub.com/browse/loanDetail.acti...
# 1229   https://lendingclub.com/browse/loanDetail.acti...
# 1287   https://lendingclub.com/browse/loanDetail.acti...
# 1304   https://lendingclub.com/browse/loanDetail.acti...
# ...                                                  ...
# 3225   https://lendingclub.com/browse/loanDetail.acti...
# 3243   https://lendingclub.com/browse/loanDetail.acti...
# 5112   https://lendingclub.com/browse/loanDetail.acti...
# 5587   https://lendingclub.com/browse/loanDetail.acti...
# 6258   https://lendingclub.com/browse/loanDetail.acti...
# 7317   https://lendingclub.com/browse/loanDetail.acti...
# 7937   https://lendingclub.com/browse/loanDetail.acti...
# 9858   https://lendingclub.com/browse/loanDetail.acti...
# 10376  https://lendingclub.com/browse/loanDetail.acti...
# 11234  https://lendingclub.com/browse/loanDetail.acti...
# 13790  https://lendingclub.com/browse/loanDetail.acti...
# 13800  https://lendingclub.com/browse/loanDetail.acti...
# 15773  https://lendingclub.com/browse/loanDetail.acti...
# 16383  https://lendingclub.com/browse/loanDetail.acti...
# 17717  https://lendingclub.com/browse/loanDetail.acti...
# 18805  https://lendingclub.com/browse/loanDetail.acti...
# 19404  https://lendingclub.com/browse/loanDetail.acti...
# 20391  https://lendingclub.com/browse/loanDetail.acti...
# 22208  https://lendingclub.com/browse/loanDetail.acti...
# 22978  https://lendingclub.com/browse/loanDetail.acti...
# 25018  https://lendingclub.com/browse/loanDetail.acti...
# 25260  https://lendingclub.com/browse/loanDetail.acti...
# 25932  https://lendingclub.com/browse/loanDetail.acti...
# 29694  https://lendingclub.com/browse/loanDetail.acti...
# 30870  https://lendingclub.com/browse/loanDetail.acti...
# 31311  https://lendingclub.com/browse/loanDetail.acti...
# 33493  https://lendingclub.com/browse/loanDetail.acti...
# 34259  https://lendingclub.com/browse/loanDetail.acti...
# 36306  https://lendingclub.com/browse/loanDetail.acti...
# 39291  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                     desc             purpose  \
# 53                                         Not Disclosed  debt_consolidation
# 83       Borrower added on 12/03/11 > Needed to purch...      major_purchase
# 146      Borrower added on 10/06/11 > Consolidate a c...  debt_consolidation
# 175                                        Not Disclosed  debt_consolidation
# 219      Borrower added on 10/25/11 > This is just a ...               other
# 223      Borrower added on 10/01/11 > I'm glad that i...    home_improvement
# 254                                        Not Disclosed      major_purchase
# 274                                        Not Disclosed                 car
# 421                                        Not Disclosed  debt_consolidation
# 434                                        Not Disclosed         credit_card
# 439      Borrower added on 08/08/11 > Looking to try ...  debt_consolidation
# 478                                        Not Disclosed  debt_consolidation
# 656      Borrower added on 11/05/11 > Winter is setti...    home_improvement
# 657                                        Not Disclosed               other
# 778                                        Not Disclosed      small_business
# 789                                        Not Disclosed                 car
# 947                                        Not Disclosed               other
# 966                                        Not Disclosed    home_improvement
# 979                                        Not Disclosed               other
# 981      Borrower added on 05/21/11 > Vintage travel ...      major_purchase
# 983      Borrower added on 05/06/11 > Kawasaki Ninja ...                 car
# 992      Borrower added on 03/11/11 > pay of motorcyc...               other
# 994                                        Not Disclosed      major_purchase
# 998                                        Not Disclosed      major_purchase
# 1017     Borrower added on 05/26/10 > Will use funds ...            vacation
# 1063                                       Not Disclosed         credit_card
# 1161     Borrower added on 09/19/11 > Plan to purchas...      major_purchase
# 1229                                       Not Disclosed         credit_card
# 1287     Borrower added on 10/24/11 > Am currently us...      small_business
# 1304                                       Not Disclosed    home_improvement
# ...                                                  ...                 ...
# 3225                                       Not Disclosed  debt_consolidation
# 3243     Borrower added on 09/13/10 > I will be using...  debt_consolidation
# 5112     Borrower added on 07/27/11 > I want to use $...             wedding
# 5587     Borrower added on 08/09/10 > This will pay d...  debt_consolidation
# 6258                                       Not Disclosed  debt_consolidation
# 7317   I Need money to have in reserve for when clien...      small_business
# 7937    573933 added on 11/13/09 > I plan to use thes...      small_business
# 9858    584314 added on 12/03/09 > I own Metalcraft F...      small_business
# 10376    Borrower added on 05/06/11 > I am planning o...      major_purchase
# 11234                                      Not Disclosed  debt_consolidation
# 13790                                      Not Disclosed      major_purchase
# 13800    Borrower added on 02/01/11 > Expanding an e-...      small_business
# 15773    Borrower added on 12/21/09 > This Loan is to...  debt_consolidation
# 16383                                      Not Disclosed  debt_consolidation
# 17717                                      Not Disclosed  debt_consolidation
# 18805   Our current business name is Premier Pets and...      small_business
# 19404                                      Not Disclosed         credit_card
# 20391                                      Not Disclosed  debt_consolidation
# 22208    Borrower added on 10/22/10 > The intent of t...  debt_consolidation
# 22978    Borrower added on 09/20/10 > Borrower added ...    renewable_energy
# 25018    Borrower added on 11/30/11 > We will be usin...         credit_card
# 25260    Borrower added on 11/05/10 > Funds to be use...               other
# 25932                                      Not Disclosed  debt_consolidation
# 29694   567538 added on 11/04/09 > I would really lik...  debt_consolidation
# 30870                                      Not Disclosed              moving
# 31311    Borrower added on 12/15/10 > Hi all, I am lo...  debt_consolidation
# 33493    Borrower added on 01/30/11 > I currently run...      small_business
# 34259  Loan needed for a short term of 12 months to c...      small_business
# 36306                                      Not Disclosed               other
# 39291                                      Not Disclosed               other
#
#                                                    title zip_code addr_state  \
# 53                                      Credit card loan    970xx         OR
# 83                                   Major Purchase Loan    275xx         NC
# 146                                   Loan Consolidation    275xx         NC
# 175                                             pay offs    275xx         NC
# 219                                      Motorcycle Loan    900xx         CA
# 223                                          Add on room    900xx         CA
# 254                                    Personal Car Loan    900xx         CA
# 274                                                  car    900xx         CA
# 421                              Debt Consolidation Loan    900xx         CA
# 434                            Credit Card Consuladation    900xx         CA
# 439                                  AMEX/CITI CARD DEBT    900xx         CA
# 478                                         Stacy's Loan    900xx         CA
# 656                                        Roof Disaster    841xx         UT
# 657                                                 Roof    841xx         UT
# 778                                        Business Loan    212xx         MD
# 789                                                SRAMV    212xx         MD
# 947                                           Other Loan    923xx         CA
# 966                                Home Improvement Loan    923xx         CA
# 979                                           Other Loan    923xx         CA
# 981                                      Vintage Trailer    923xx         CA
# 983                                      Motorcycle loan    923xx         CA
# 992                                                   hd    923xx         CA
# 994                                           Roketa 800    923xx         CA
# 998                                       Michael's Loan    923xx         CA
# 1017                                          $1000 loan    923xx         CA
# 1063                             Delete credit card debt    923xx         CA
# 1161                                      Signature Loan    335xx         FL
# 1229                                              7kLoan    335xx         GA
# 1287                                 Small Business Loan    980xx         WA
# 1304                                     kitchen remodel    980xx         WA
# ...                                                  ...      ...        ...
# 3225                                           Debt Loan    773xx         TX
# 3243                                  Debt Consolidation    773xx         TX
# 5112                 Debt Consolidation/Wedding Expenses    770xx         TX
# 5587                                  Consolidation loan    956xx         CA
# 6258                                          debt cons.    908xx         CA
# 7317                    Need capital to make adjustments    945xx         CA
# 7937                                 Win/Win Opportunity    799xx         TX
# 9858   funding for brewery stainless( we build them a...    972xx         OR
# 10376                                        Consolidate    829xx         WY
# 11234                                     Unsecured Loan    850xx         AZ
# 13790                                               Boat    300xx         GA
# 13800                                Small Business Loan    300xx         GA
# 15773                              Financially Free Loan    100xx         NY
# 16383                                       Debt Removal    112xx         NY
# 17717              Debt (Credit Cards) Cosolidation Loan    208xx         MD
# 18805                  Pet Shop Expansion and Rebranding    922xx         CA
# 19404                                   Credit Card Loan    774xx         TX
# 20391                                 Debt Consolidation    080xx         NJ
# 22208                                combined debts loan    317xx         GA
# 22978           SOLID GREEN Business needs a little help    024xx         MA
# 25018                                   Credit Card Loan    707xx         LA
# 25260                                         Investment    480xx         MI
# 25932                                      new beginning    308xx         GA
# 29694                                     SON IN COLLEGE    015xx         MA
# 30870                         Moving and Transition Loan    490xx         MI
# 31311                              Bobby's Consolidation    660xx         KS
# 33493                                    Working Capital    121xx         NY
# 34259                        Short Term Financing Needed    103xx         NY
# 36306                                 Debt consolidation    402xx         KY
# 39291                                 bill consolidation    312xx         GA
#
#         dti  delinq_2yrs earliest_cr_line  inq_last_6mths  open_acc  pub_rec  \
# 53     3.19            0           Jun-94               0         6        0
# 83     8.06            0           Jan-98               0        14        0
# 146    6.35            1           Feb-94               0        13        0
# 175    4.41            0           Feb-76               0         6        0
# 219   15.72            0           Jun-93               0         6        0
# 223   11.65            0           Dec-91               0         7        0
# 254   20.34            0           Oct-99               0         8        0
# 274    4.36            0           Apr-97               0         8        0
# 421   15.64            0           Aug-99               0         8        0
# 434    3.72            0           Nov-02               0         9        0
# 439    0.41            0           Oct-99               0         7        0
# 478    5.62            0           Nov-73               0        10        0
# 656    7.97            0           Oct-93               0         9        0
# 657    8.34            0           Aug-86               0        11        0
# 778    7.53            0           Sep-05               0         6        0
# 789    2.83            0           Feb-84               0         6        0
# 947   16.48            0           Jun-00               0         7        0
# 966   10.90            0           Jan-85               0        11        0
# 979    0.85            0           Aug-94               0         6        0
# 981    4.91            0           Apr-84               0         7        0
# 983   15.00            0           Dec-95               0         9        0
# 992    8.93            0           Mar-00               0        13        0
# 994    8.76            0           Dec-98               0         9        0
# 998    1.14            0           Mar-98               0         8        0
# 1017   1.76            0           Apr-95               0         7        0
# 1063  10.13            0           Jun-77               0         8        0
# 1161   4.09            0           Nov-70               0         6        0
# 1229   6.53            0           Jul-90               0        10        0
# 1287  14.14            0           Dec-95               0         5        0
# 1304   7.54            0           Nov-94               0         6        0
# ...     ...          ...              ...             ...       ...      ...
# 3225  22.40            0           Feb-00               3        13        0
# 3243   8.00            0           Jun-01               2        11        1
# 5112  17.15            0           Aug-01               3        30        0
# 5587   1.11            0           Feb-97               1         2        0
# 6258   6.79            0           Nov-02               2         4        0
# 7317  23.04            0           Sep-89               3        13        0
# 7937  10.45            0           Mar-00               1        12        0
# 9858   5.72            0           Dec-05               1         6        0
# 10376 18.33            0           Dec-00               1         2        0
# 11234 22.28            0           Jan-01               1         9        0
# 13790  1.44            0           Feb-08               0         3        0
# 13800  4.06            0           Apr-06               1        38        0
# 15773 15.45            0           Jun-01               1         3        0
# 16383 22.59            0           Oct-03               0        15        0
# 17717 18.61            0           Sep-04               1         3        0
# 18805 21.34            1           Sep-98               0         9        1
# 19404  8.30            0           Feb-99               0         8        0
# 20391 15.42            0           Apr-02               0        27        0
# 22208 22.41            0           Sep-90               0         9        0
# 22978 20.74            0           Oct-95               1        11        0
# 25018 12.27            0           Nov-94               2         8        0
# 25260 12.92            0           Nov-00               0         7        0
# 25932 16.33            0           Jun-97               1        30        1
# 29694 19.87            0           Feb-88               1        28        0
# 30870 12.19            0           Oct-84               0        26        0
# 31311 15.88            0           Apr-98               1         7        0
# 33493  4.00            0           Apr-99               0        11        0
# 34259  5.36            3           Jan-98               3         7        0
# 36306 14.95            0           Nov-87               3        25        0
# 39291 21.55            0           Dec-96               1        30        0
#
#        revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv  \
# 53          5770       23.00         22       0.00           0.00
# 83          3852        4.70         21       0.00           0.00
# 146         6970        4.00         25       0.00           0.00
# 175         8172       26.70         16       0.00           0.00
# 219        12600       33.10          9       0.00           0.00
# 223        45907        1.70         37       0.00           0.00
# 254         3480       18.90         11       0.00           0.00
# 274        11624       46.30         26       0.00           0.00
# 421         7684       30.50         22       0.00           0.00
# 434         7512       36.50         14       0.00           0.00
# 439         1645        8.60         24       0.00           0.00
# 478        14495       50.00         36       0.00           0.00
# 656         1124        3.00         16       0.00           0.00
# 657         2035        3.90         17       0.00           0.00
# 778          665       26.60         10       0.00           0.00
# 789         3931       10.60         17       0.00           0.00
# 947         5881       25.60         16       0.00           0.00
# 966         1796        2.80         34       0.00           0.00
# 979           12        0.10         11       0.00           0.00
# 981         3452        7.40         27       0.00           0.00
# 983          822        2.70         41       0.00           0.00
# 992        17143       26.10         35       0.00           0.00
# 994         5912       28.30         27       0.00           0.00
# 998         1621        7.20         14       0.00           0.00
# 1017        5950       15.80         27       0.00           0.00
# 1063        3178       12.30         23       0.00           0.00
# 1161        1512        6.70         28       0.00           0.00
# 1229        2334        5.50         30       0.00           0.00
# 1287       16320       34.40         34       0.00           0.00
# 1304        4137        9.50         18       0.00           0.00
# ...          ...         ...        ...        ...            ...
# 3225       50342       92.50         26       0.00           0.00
# 3243       10957       99.60         33       0.00           0.00
# 5112       13346       38.40         63       0.00           0.00
# 5587        3131       69.60         19       0.00           0.00
# 6258       18621       99.70          6       0.00           0.00
# 7317       24280       93.40         38       0.00           0.00
# 7937       14718       40.40         31       0.00           0.00
# 9858         500       83.30         12       0.00           0.00
# 10376       3900       97.50         15       0.00           0.00
# 11234      35493       98.00          9       0.00           0.00
# 13790       1113       33.70          4       0.00           0.00
# 13800       6052       58.20         59       0.00           0.00
# 15773      10190       98.90         20       0.00           0.00
# 16383      16687       98.20         24       0.00           0.00
# 17717       8777       97.50         13       0.00           0.00
# 18805      13337       59.00         15       0.00           0.00
# 19404      12990       97.70         31       0.00           0.00
# 20391      20081       51.60         35       0.00           0.00
# 22208      68051       93.10         19       0.00           0.00
# 22978      90633       98.60         18       0.00           0.00
# 25018      17522       99.00         28       0.00           0.00
# 25260       4324       90.10         23       0.00           0.00
# 25932      26864       78.50         47       0.00           0.00
# 29694      90063       79.60         53       0.00           0.00
# 30870      24148       35.60         38       0.00           0.00
# 31311      31334       93.30         24       0.00           0.00
# 33493       5675       65.20         19       0.00           0.00
# 34259       5848       24.30         18       0.00           0.00
# 36306      43958       52.10         57     578.35         578.35
# 39291      28580       67.00         60       0.00           0.00
#
#        total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 53       10,858.52        10,858.52        10,000.00         858.52
# 83       13,148.14        13,148.14        12,000.00       1,148.14
# 146      16,828.31        16,828.31        16,000.00         828.31
# 175      12,696.91        12,670.45        12,000.00         696.91
# 219       3,257.86         3,257.86         3,000.00         257.86
# 223      16,435.16        16,352.99        15,000.00       1,435.16
# 254       3,643.45         3,565.37         3,500.00         143.45
# 274       5,428.63         5,428.63         5,050.00         378.63
# 421      10,956.78        10,929.38        10,000.00         956.78
# 434      10,423.22        10,368.93         9,600.00         823.22
# 439       3,800.14         3,800.14         3,500.00         300.14
# 478       2,099.15         2,099.15         2,000.00          99.15
# 656       8,765.41         8,765.41         8,000.00         765.41
# 657      10,956.78        10,929.38        10,000.00         956.78
# 778       4,560.14         4,560.14         4,200.00         360.14
# 789       8,686.49         8,686.49         8,000.00         686.49
# 947       5,451.32         5,451.32         5,000.00         451.32
# 966       5,127.14         5,127.14         5,000.00         127.14
# 979       3,257.26         3,230.12         3,000.00         257.26
# 981       3,257.26         3,257.26         3,000.00         257.26
# 983       3,908.70         3,881.56         3,600.00         308.70
# 992       4,694.54         4,642.38         4,500.00         194.54
# 994       2,714.15         2,714.15         2,500.00         214.15
# 998       5,894.01         5,894.01         5,600.00         294.01
# 1017      1,082.59         1,082.59         1,000.00          82.59
# 1063      2,605.79         2,605.79         2,400.00         205.79
# 1161      7,039.73         7,039.73         6,425.00         614.73
# 1229      7,134.17         7,108.69         7,000.00         134.17
# 1287     10,956.78        10,956.78        10,000.00         956.78
# 1304     12,664.20        12,664.20        12,000.00         664.20
# ...            ...              ...              ...            ...
# 3225     36,121.42        35,979.14        30,000.00       6,121.42
# 3243     32,897.19        32,856.07        20,000.00      12,897.19
# 5112     19,662.49        19,628.59        14,500.00       5,162.49
# 5587      3,007.35         3,007.35         1,066.94       1,940.41
# 6258     32,863.39        32,822.31        20,000.00      12,863.39
# 7317     18,069.37        12,013.69        13,875.00       4,194.37
# 7937     17,715.75        17,539.55        13,000.00       4,691.19
# 9858     25,166.28        25,134.82        20,000.00       5,166.28
# 10376    20,664.88        20,664.88        16,000.00       4,664.88
# 11234    46,829.05        46,789.83        29,850.00      16,979.05
# 13790     7,030.48         7,030.48         4,700.00       2,330.48
# 13800     3,052.51         3,052.51         1,789.07       1,263.44
# 15773    29,421.54        29,421.54        21,600.00       7,782.29
# 16383    10,258.65        10,246.67         1,380.65       5,524.66
# 17717    20,481.74        20,385.89        19,125.00       1,356.74
# 18805    16,472.87        10,734.92        10,532.09       5,048.91
# 19404    31,602.40        31,602.40        25,000.00       6,602.40
# 20391    15,463.37        15,463.37         6,486.18       7,890.17
# 22208    24,413.40        23,730.79        15,200.00       9,213.40
# 22978    14,687.91        13,409.74         2,729.59       2,970.47
# 25018    35,626.82        35,590.09        24,250.00      11,376.82
# 25260    39,069.98        38,744.40        24,000.00      15,069.98
# 25932     1,883.25         1,873.85         1,040.34         842.91
# 29694     8,477.44         8,445.30         2,486.40       1,983.54
# 30870    51,820.91        51,780.42        32,000.00      19,820.91
# 31311     8,955.04         8,955.04         8,800.00         155.04
# 33493    12,808.82        12,385.37         4,612.37       7,025.45
# 34259     8,208.90         6,737.14         3,127.09       2,552.16
# 36306    32,724.17        32,724.17        18,521.63      14,202.54
# 39291    24,249.07        24,166.03        14,600.00       9,649.07
#
#        total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  \
# 53                   0.00        0.00                     0.00       Nov-13
# 83                   0.00        0.00                     0.00       Dec-14
# 146                  0.00        0.00                     0.00       Oct-12
# 175                  0.00        0.00                     0.00       May-12
# 219                  0.00        0.00                     0.00       Dec-13
# 223                  0.00        0.00                     0.00       Oct-14
# 254                  0.00        0.00                     0.00       Sep-12
# 274                  0.00        0.00                     0.00       Mar-13
# 421                  0.00        0.00                     0.00       Oct-14
# 434                  0.00        0.00                     0.00       Sep-14
# 439                  0.00        0.00                     0.00       Aug-14
# 478                  0.00        0.00                     0.00       Jun-12
# 656                  0.00        0.00                     0.00       Nov-14
# 657                  0.00        0.00                     0.00       Oct-14
# 778                  0.00        0.00                     0.00       May-14
# 789                  0.00        0.00                     0.00       Dec-13
# 947                  0.00        0.00                     0.00       Apr-14
# 966                  0.00        0.00                     0.00       Feb-12
# 979                  0.00        0.00                     0.00       Jun-14
# 981                  0.00        0.00                     0.00       Jun-14
# 983                  0.00        0.00                     0.00       May-14
# 992                  0.00        0.00                     0.00       Mar-12
# 994                  0.00        0.00                     0.00       Jan-14
# 998                  0.00        0.00                     0.00       Mar-12
# 1017                 0.00        0.00                     0.00       Mar-12
# 1063                 0.00        0.00                     0.00       Aug-14
# 1161                 0.00        0.00                     0.00       Oct-14
# 1229                 0.00        0.00                     0.00       Feb-12
# 1287                 0.00        0.00                     0.00       Nov-14
# 1304                 0.00        0.00                     0.00       Oct-12
# ...                   ...         ...                      ...          ...
# 3225                 0.00        0.00                     0.00       Mar-12
# 3243                 0.00        0.00                     0.00       Oct-15
# 5112                 0.00        0.00                     0.00       Apr-13
# 5587                 0.00        0.00                     0.00       Jan-11
# 6258                 0.00        0.00                     0.00       Mar-16
# 7317                 0.00        0.00                     0.00       Sep-10
# 7937                24.56        0.00                     0.00       Dec-12
# 9858                 0.00        0.00                     0.00       Jun-11
# 10376                0.00        0.00                     0.00       Sep-12
# 11234                0.00        0.00                     0.00       Jun-14
# 13790                0.00        0.00                     0.00       Mar-14
# 13800                0.00        0.00                     0.00       Mar-12
# 15773               39.26        0.00                     0.00       Feb-13
# 16383               30.48    3,322.86                   598.11       Dec-13
# 17717                0.00        0.00                     0.00       Sep-11
# 18805                0.00      891.87                   160.54       Sep-11
# 19404                0.00        0.00                     0.00       Feb-13
# 20391                0.00    1,087.02                    10.54       Sep-14
# 22208                0.00        0.00                     0.00       Jan-15
# 22978                0.00    8,987.85                   817.72       May-11
# 25018                0.00        0.00                     0.00       Apr-14
# 25260                0.00        0.00                     0.00       Nov-15
# ...
# 25018            16.72    2011-12-01       24.11          2016-02-01
# 25260            16.75    2010-11-01       21.14          2016-04-01
# 25932            16.72    2010-11-01       21.14          2016-04-01
# 29694            16.93    2009-11-01       21.21          2016-04-01
# 30870            18.46    2011-04-01       21.59          2016-04-01
# 31311            15.93    2010-12-01       21.14          2016-05-01
# 33493            15.87    2011-02-01       21.59          2012-12-01
# 34259            16.52    2009-07-01       20.11          2016-04-01
# 36306            17.61    2011-06-01       24.59          2016-05-01
# 39291            17.50    2011-03-01       21.59          2016-05-01
#
#       emp_title_provided  source_verification  income_verification  \
# 53         Not Disclosed                False                False
# 83             Disclosed                 True                 True
# 146        Not Disclosed                 True                 True
# 175            Disclosed                False                False
# 219            Disclosed                False                False
# 223            Disclosed                False                 True
# 254            Disclosed                 True                 True
# 274            Disclosed                 True                 True
# 421            Disclosed                False                 True
# 434            Disclosed                 True                 True
# 439            Disclosed                 True                 True
# 478            Disclosed                False                 True
# 656            Disclosed                False                 True
# 657            Disclosed                 True                 True
# 778            Disclosed                False                False
# 789            Disclosed                False                False
# 947            Disclosed                False                False
# 966            Disclosed                False                 True
# 979        Not Disclosed                False                 True
# 981        Not Disclosed                False                False
# 983            Disclosed                False                False
# 992            Disclosed                False                False
# 994            Disclosed                 True                 True
# 998            Disclosed                False                False
# 1017           Disclosed                 True                 True
# 1063           Disclosed                False                False
# 1161           Disclosed                False                False
# 1229           Disclosed                 True                 True
# 1287       Not Disclosed                 True                 True
# 1304           Disclosed                False                False
# ...                  ...                  ...                  ...
# 3225           Disclosed                False                 True
# 3243           Disclosed                False                 True
# 5112           Disclosed                False                 True
# 5587           Disclosed                False                 True
# 6258           Disclosed                False                False
# 7317           Disclosed                False                False
# 7937       Not Disclosed                False                False
# 9858       Not Disclosed                False                False
# 10376          Disclosed                 True                 True
# 11234          Disclosed                False                 True
# 13790          Disclosed                 True                 True
# 13800          Disclosed                False                False
# 15773          Disclosed                False                 True
# 16383          Disclosed                False                 True
# 17717          Disclosed                False                False
# 18805          Disclosed                False                 True
# 19404          Disclosed                False                 True
# 20391          Disclosed                False                False
# 22208          Disclosed                False                 True
# 22978          Disclosed                False                 True
# 25018          Disclosed                False                 True
# 25260          Disclosed                False                 True
# 25932          Disclosed                 True                 True
# 29694          Disclosed                False                False
# 30870          Disclosed                False                 True
# 31311          Disclosed                False                 True
# 33493      Not Disclosed                 True                 True
# 34259          Disclosed                False                 True
# 36306      Not Disclosed                False                 True
# 39291          Disclosed                False                False
#
#            purpose_mapped zip_code_str state_code       city_code  \
# 53     debt_consolidation          970         OR        ANTELOPE
# 83         major_purchase          275         NC          ANGIER
# 146    debt_consolidation          275         NC          ANGIER
# 175    debt_consolidation          275         NC          ANGIER
# 219                 other          900         CA     LOS ANGELES
# 223      home_improvement          900         CA     LOS ANGELES
# 254        major_purchase          900         CA     LOS ANGELES
# 274                  Auto          900         CA     LOS ANGELES
# 421    debt_consolidation          900         CA     LOS ANGELES
# 434    debt_consolidation          900         CA     LOS ANGELES
# 439    debt_consolidation          900         CA     LOS ANGELES
# 478    debt_consolidation          900         CA     LOS ANGELES
# 656      home_improvement          841         UT  SALT LAKE CITY
# 657                 other          841         UT  SALT LAKE CITY
# 778        small_business          212         MD       BALTIMORE
# 789                  Auto          212         MD       BALTIMORE
# 947                 other          923         CA        ADELANTO
# 966      home_improvement          923         CA        ADELANTO
# 979                 other          923         CA        ADELANTO
# 981        major_purchase          923         CA        ADELANTO
# 983                  Auto          923         CA        ADELANTO
# 992                 other          923         CA        ADELANTO
# 994        major_purchase          923         CA        ADELANTO
# 998        major_purchase          923         CA        ADELANTO
# 1017             vacation          923         CA        ADELANTO
# 1063   debt_consolidation          923         CA        ADELANTO
# 1161       major_purchase          335         FL            BALM
# 1229   debt_consolidation          335         FL            BALM
# 1287       small_business          980         WA          AUBURN
# 1304     home_improvement          980         WA          AUBURN
# ...                   ...          ...        ...             ...
# 3225   debt_consolidation          773         TX             ACE
# 3243   debt_consolidation          773         TX             ACE
# 5112              wedding          770         TX         HOUSTON
# 5587   debt_consolidation          956         CA     AMADOR CITY
# 6258   debt_consolidation          908         CA      LONG BEACH
# 7317       small_business          945         CA         ALAMEDA
# 7937       small_business          799         TX         EL PASO
# 9858       small_business          972         OR        PORTLAND
# 10376      major_purchase          829         WY       BONDURANT
# 11234  debt_consolidation          850         AZ         PHOENIX
# 13790      major_purchase          300         GA      ALPHARETTA
# 13800      small_business          300         GA      ALPHARETTA
# 15773  debt_consolidation          100         NY        NEW YORK
# 16383  debt_consolidation          112         NY        BROOKLYN
# 17717  debt_consolidation          208         MD          ASHTON
# 18805      small_business          922         CA         BANNING
# 19404  debt_consolidation          774         TX           ALIEF
# 20391  debt_consolidation          080         NJ         ALLOWAY
# 22208  debt_consolidation          317         GA          ALBANY
# 22978    home_improvement          024         MA         BELMONT
# 25018  debt_consolidation          707         LA           ADDIS
# 25260               other          480         MI         ALGONAC
# 25932  debt_consolidation          308         GA         APPLING
# 29694  debt_consolidation          015         MA   WEST MILLBURY
# 30870    home_improvement          490         MI         ALLEGAN
# 31311  debt_consolidation          660         KS        ATCHISON
# 33493      small_business          121         NY  WEST COXSACKIE
# 34259      small_business          103         NY   STATEN ISLAND
# 36306               other          402         KY      LOUISVILLE
# 39291               other          312         GA           MACON
#
#       earliest_cr_line_dt earliest_cr_line_dt_fine time_delta  time_delta_int  \
# 53             1994-06-01               1994-06-01  5997 days           16.42
# 83             1998-01-01               1998-01-01  5082 days           13.91
# 146            1994-02-01               1994-02-01  6451 days           17.66
# 175            1976-02-01               1976-02-01 12753 days           34.92
# 219            1993-06-01               1993-06-01  6696 days           18.33
# 223            1991-12-01               1991-12-01  7244 days           19.83
# 254            1999-10-01               1999-10-01  4200 days           11.50
# 274            1997-04-01               1997-04-01  5054 days           13.84
# 421            1999-08-01               1999-08-01  4414 days           12.09
# 434            2002-11-01               2002-11-01  3195 days            8.75
# 439            1999-10-01               1999-10-01  4322 days           11.83
# 478            1973-11-01               1973-11-01 13665 days           37.41
# 656            1993-10-01               1993-10-01  6605 days           18.08
# 657            1986-08-01               1986-08-01  9192 days           25.17
# 778            2005-09-01               2005-09-01  2068 days            5.66
# 789            1984-02-01               1984-02-01  9800 days           26.83
# 947            2000-06-01               2000-06-01  4200 days           11.50
# 966            1985-01-01               1985-01-01  9708 days           26.58
# 979            1994-08-01               1994-08-01  6148 days           16.83
# 981            1984-04-01               1984-04-01  9891 days           27.08
# 983            1995-12-01               1995-12-01  5630 days           15.41
# 992            2000-03-01               2000-03-01  4017 days           11.00
# 994            1998-12-01               1998-12-01  4414 days           12.09
# 998            1998-03-01               1998-03-01  4658 days           12.75
# 1017           1995-04-01               1995-04-01  5509 days           15.08
# 1063           1977-06-01               1977-06-01 12479 days           34.17
# 1161           1970-11-01               1970-11-01 14914 days           40.83
# 1229           1990-07-01               1990-07-01  7609 days           20.83
# 1287           1995-12-01               1995-12-01  5814 days           15.92
# 1304           1994-11-01               1994-11-01  6056 days           16.58
# ...                   ...                      ...        ...             ...
# 3225           2000-02-01               2000-02-01  4046 days           11.08
# 3243           2001-06-01               2001-06-01  3379 days            9.25
# 5112           2001-08-01               2001-08-01  3652 days           10.00
# 5587           1997-02-01               1997-02-01  4929 days           13.50
# 6258           2002-11-01               2002-11-01  3042 days            8.33
# 7317           1989-09-01               1989-09-01  6696 days           18.33
# 7937           2000-03-01               2000-03-01  3532 days            9.67
# 9858           2005-12-01               2005-12-01  1461 days            4.00
# 10376          2000-12-01               2000-12-01  3803 days           10.41
# 11234          2001-01-01               2001-01-01  3803 days           10.41
# 13790          2008-02-01               2008-02-01  1155 days            3.16
# 13800          2006-04-01               2006-04-01  1767 days            4.84
# 15773          2001-06-01               2001-06-01  3105 days            8.50
# 16383          2003-10-01               2003-10-01  2922 days            8.00
# 17717          2004-09-01               2004-09-01  2403 days            6.58
# 18805          1998-09-01               1998-09-01  3956 days           10.83
# 19404          1999-02-01               1999-02-01  4686 days           12.83
# 20391          2002-04-01               2002-04-01  3409 days            9.33
# 22208          1990-09-01               1990-09-01  7335 days           20.08
# 22978          1995-10-01               1995-10-01  5449 days           14.92
# 25018          1994-11-01               1994-11-01  6239 days           17.08
# 25260          2000-11-01               2000-11-01  3652 days           10.00
# 25932          1997-06-01               1997-06-01  4901 days           13.42
# 29694          1988-02-01               1988-02-01  7944 days           21.75
# 30870          1984-10-01               1984-10-01  9678 days           26.50
# 31311          1998-04-01               1998-04-01  4627 days           12.67
# 33493          1999-04-01               1999-04-01  4324 days           11.84
# 34259          1998-01-01               1998-01-01  4199 days           11.50
# 36306          1987-11-01               1987-11-01  8613 days           23.58
# 39291          1996-12-01               1996-12-01  5203 days           14.25
#
#        open_acct_ratio
# 53                0.27
# 83                0.67
# 146               0.52
# 175               0.38
# 219               0.67
# 223               0.19
# 254               0.73
# 274               0.31
# 421               0.36
# 434               0.64
# 439               0.29
# 478               0.28
# 656               0.56
# 657               0.65
# 778               0.60
# 789               0.35
# 947               0.44
# 966               0.32
# 979               0.55
# 981               0.26
# 983               0.22
# 992               0.37
# 994               0.33
# 998               0.57
# 1017              0.26
# 1063              0.35
# 1161              0.21
# 1229              0.33
# 1287              0.15
# 1304              0.33
# ...                ...
# 3225              0.50
# 3243              0.33
# 5112              0.48
# 5587              0.11
# 6258              0.67
# 7317              0.34
# 7937              0.39
# 9858              0.50
# 10376             0.13
# 11234             1.00
# 13790             0.75
# 13800             0.64
# 15773             0.15
# 16383             0.62
# 17717             0.23
# 18805             0.60
# 19404             0.26
# 20391             0.77
# 22208             0.47
# 22978             0.61
# 25018             0.29
# 25260             0.30
# 25932             0.64
# 29694             0.53
# 30870             0.68
# 31311             0.29
# 33493             0.58
# 34259             0.39
# 36306             0.44
# 39291             0.50
#
# [39663 rows x 61 columns]

# %%
print((loan_data.grade.unique()))
print((loan_data.sub_grade.unique()))
# Out:
# ['A' 'B' 'E' 'D' 'C' 'F' 'G']
# ['A3' 'B5' 'E4' 'E2' 'B4' 'A5' 'B1' 'D2' 'E1' 'B3' 'A4' 'D4' 'C4' 'C1'
#  'B2' 'D1' 'D5' 'C2' 'C5' 'E3' 'D3' 'A1' 'F1' 'F4' 'C3' 'A2' 'E5' 'G1'
#  'F3' 'G2' 'F2' 'G4' 'G3' 'F5' 'G5']

# %%
#from above it, looks like grade, sub_grade and int_rate are related.
print(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].median())
# Out:
# grade  sub_grade
# A      A1           5.42
#        A2           5.99
#        A3           7.14
#        A4           7.51
#        A5           8.49
# B      B1           9.91
#        B2          10.59
#        B3          10.99
#        B4          11.49
#        B5          11.99
# C      C1          12.99
#        C2          13.49
#        C3          13.57
#        C4          13.92
#        C5          14.26
# D      D1          14.61
#        D2          15.21
#        D3          15.58
#        D4          15.95
#        D5          16.32
# E      E1          16.45
#        E2          16.82
#        E3          17.19
#        E4          17.56
#        E5          17.93
# F      F1          18.30
#        F2          18.67
#        F3          20.99
#        F4          19.41
#        F5          19.79
# G      G1          20.16
#        G2          20.48
#        G3          20.90
#        G4          21.27
#        G5          21.59
# Name: int_rate_f, dtype: float64

# %%
# Ok, int_rate is related to grade and sub_grade. Analyse bit further.
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('A','A1')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('A','A2')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('A','A3')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('A','A4')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('A','A5')).unique()))

print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('B','B1')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('B','B2')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('B','B3')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('B','B4')).unique()))
print(np.sort(loan_data.groupby(by=['grade','sub_grade'])['int_rate_f'].get_group(('B','B5')).unique()))
# Out:
# [5.42 6.03 6.39 7.05 7.12 7.37]
# [5.79 5.99 6.62 6.76 7.4  7.43 7.68]
# [6.17 6.92 6.99 7.14 7.42 7.51 7.74 7.75 8.  ]
# [6.   6.54 7.29 7.49 7.51 7.9  7.91 8.07 8.32 8.59 9.07 9.32]
# [6.91 7.66 7.88 8.38 8.49 8.63 8.9  8.94 9.38 9.63]
# [ 6.    8.7   8.88  9.2   9.45  9.63  9.67  9.7   9.88  9.91  9.99 10.2
#  10.38 10.95 11.14]
# [ 6.    9.01  9.25  9.51  9.76 10.   10.01 10.25 10.51 10.59 10.65 10.75
#  11.14 11.26 11.48]
# [ 6.    9.33  9.62  9.83 10.08 10.33 10.37 10.62 10.83 10.99 11.12 11.58
#  11.63 11.71 11.83]
# [ 9.64  9.99 10.14 10.39 10.64 10.74 10.99 11.14 11.49 11.89 12.12 12.18
#  12.42]
# [ 6.    9.96 10.36 10.46 10.71 10.96 11.11 11.36 11.46 11.86 11.99 12.21
#  12.53 12.62 12.69]

# %%
# Although, there is a clear trend in int_rate and grade/sub_grade, there appears to be some deviation from trend. 
# Try correlation matrix technique to identify the relation ships.
# First, convert grade and subgrade to numerical value

sub_grade_map={'A1':11,'A2':12,'A3':13,'A4':14,'A5':15,'B1':21,'B2':22,'B3':23,'B4':24,'B5':25,'C1':31,'C2':32,'C3':33,'C4':34,'C5':35,
              'D1':41,'D2':42,'D3':43,'D4':44,'D5':45,'E1':51,'E2':52,'E3':53,'E4':54,'E5':55,'F1':61,'F2':62,'F3':63,'F4':64,'F5':65,
              'G1':71,'G2':72,'G3':73,'G4':74,'G5':75}
loan_data['sub_grade_numeric']=loan_data['sub_grade'].map(sub_grade_map)

# %%
# Find correlation amoong the most probable variables
loan_data_corr=loan_data[['loan_amnt','int_rate_f','sub_grade_numeric','installment','emp_length','annual_inc_log2',
                            'dti','funded_amnt']].corr()

# %%
fig=plt.figure(figsize=(8, 8), dpi=70, facecolor='w', edgecolor='k')
sns.set(style="darkgrid")
sns.heatmap(loan_data_corr, annot=True, annot_kws={"size": 7})
plt.show()

# %% [markdown]
# ### Observation
# From the above , it is clear that int_rate, sub grades and grades are related strongly. <br>
# For analysis, we will drop 'Grade' and 'Subgrade' and use Interest.

# %% [markdown]
# ### Delete Unnecessary cols
# The following are the main assumptions -
#  - Columns that have unique values for each of the observation are dropped.These are system identifiers
#     provided to the applications. For example 'id','member_id'<br>
#  - Columns that do not add any value to the Analysis are dropped, for example - 'last_pymnt_amnt'
#  - Columns that are generally not the cause ( but are effect) of loan status are dropped, for example 'total_rec_prncp'
#  - Columns that are highly correlated to the other variables are dropped for example 'grade','sub_grade','int_rate'
#  - Columns that have been cleaned and derived for example - int_rate_f is derived from int_rate, similarly,
#    'income verification' and 'source verification' derived from 'verification status'

# %%
#Drop columns that do not add any weight to the analysis
loan_data.drop(columns=['member_id','funded_amnt_inv','grade','sub_grade','emp_title',
                        'issue_d','url','desc','int_rate','open_acc','revol_bal','total_acc',
                       'purpose','title','zip_code','addr_state','earliest_cr_line',
                       'earliest_cr_line_dt','time_delta','out_prncp','out_prncp_inv','total_pymnt',
                       'total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee',
                       'recoveries','collection_recovery_fee','last_pymnt_amnt','city_code',
                        'last_credit_pull_d', 'last_credit_pull_dt','sub_grade_numeric','earliest_cr_line_dt_fine',
                       'last_pymnt_d','verification_status'],
                        axis=1,inplace=True)

# %%
# Extract fully paid and charged off loans for Segmented analysis
loan_data_extract=loan_data[loan_data['loan_status']!='current']
# Check Size and print few observations
print(loan_data_extract.shape)
# Out:
# (38523, 26)

# %%
# Check the missing numbers
msno.bar(loan_data_extract)

# %% [markdown]
# ## Univeriate Analysis and Segmented Analysis

# %% [markdown]
# Following the data Cleaning exercise, Univeriate and Segmented Analysis is done. Each Variable is considered <br>
# at a time and analysis is done. Box plots, Count plot or percentage stacked plot are employed as applicable.<br>

# %%
# Write a function to display subplots of box plot for given variables.
def box_plot(k,fx=16,fy=8):
    fig=plt.figure(figsize=(fx, fy), dpi=70, facecolor='w', edgecolor='k')
    sns.set(style="darkgrid")
    i=1
    for col in k:
        plt.subplot(2,3,i)
        sns.boxplot(y=col,
                    x='loan_status',
                palette='pastel',
                data=loan_data_extract)
        i=i+1

plt.show()

# %%
# Write a function to display subplots of bar plot for given variables.
def count_plot(k,fx=16,fy=8):
    fig=plt.figure(figsize=(fx, fy), dpi=90, facecolor='w', edgecolor='k')
    sns.set(style="darkgrid")
    i=1
    for col in k:
        plt.subplot(2,3,i)
        plt.xticks(rotation='vertical')
        ax=sns.countplot(y=col,
            data=loan_data_extract,
            palette='pastel',
            order=loan_data_extract[col].value_counts().index)  
        i=i+1
    
    
plt.show()

# %%
# Write a function to display a percentage stacked plot of passed variable aganist the Loan Status
def stacked_plot(a,b,fx=10,fy=8):
    x_value=a
    labl=b
    loan_data_extract_totals=loan_data_extract.groupby(by=[x_value,'loan_status'])['loan_amnt'].count().reset_index()
    loan_analysis_totals=pd.pivot_table(loan_data_extract_totals,values='loan_amnt',index=x_value,columns='loan_status').reset_index()
    
    r = range(len(loan_analysis_totals[x_value]))
    
    loan_total = [i+j for i,j in zip(loan_analysis_totals['charged off'],loan_analysis_totals['fully paid'])]
    loan_chgoff = [i / j * 100 for i,j in zip(loan_analysis_totals['charged off'], loan_total)]
    loan_paid = [i / j * 100 for i,j in zip(loan_analysis_totals['fully paid'], loan_total)]
     
    df_percents=pd.DataFrame({x_value:loan_analysis_totals[x_value],'Charged_off_perc':loan_chgoff,'Fully_paid_p':loan_paid})
    #print(df_percents)
    
    sns.set(style="ticks")
    col_mat=['b','r','g','y','c','m']
    m=np.random.randint(1,5)
    
    #ax=df_percents.plot.bar(stacked=True,figsize=(fx,fy),color=sns.color_palette("hls", 8))
    ax=df_percents.plot.bar(stacked=True,figsize=(fx,fy),color=[col_mat[m],col_mat[m-1]])
    
    for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        if height!=0:
            ax.annotate('{:.2f} %'.format(height), (p.get_x()+.25*width, p.get_y()+.5*height),ha='left',va='center',
                    rotation='vertical',
                    size='smaller')   
       
    plt.xticks(r,loan_analysis_totals[x_value],rotation='vertical')
    plt.xlabel(labl)
    plt.legend(loc='best', bbox_to_anchor=(1,1), ncol=1)
    plt.show()

# %% [markdown]
# ## Analyse Loan Amount - The amount customer has requested

# %%
box_plot(['loan_amnt'])

# %%
# Bin the loan amount into buckets and chart the plots 
loan_data_extract['loan_amnt_bin_catlg'] = pd.cut(loan_data_extract['loan_amnt'], np.linspace(0, 35000, 8))
count_plot(['loan_amnt_bin_catlg'])

# %%
stacked_plot('loan_amnt_bin_catlg','Loan Amounts vs Loan Status')

# %% [markdown]
# ### Observation
# In general, as the loan amount is increasing, the percentage of the charged off loans is increasing.<br>
# The percentage of Charged off loans is highest for the loam amounts in range 30000 - 35000. But, the number of loans in this category are less.<br>
# From the count plot, the highest number of loans is for 5000 - 10000, followed by 0 - 5000 and 10000 - 15000.
# With in top 3 high volume categories, the laons that all with in 0 -5000 are slightly likely to be charged off

# %% [markdown]
# ## Analyse impact of Funded Amount on Loan Status

# %%
box_plot(['funded_amnt'])

# %%
# Bin the funded amount and chart the plots
loan_data_extract['funded_amnt_bin_catlg'] = pd.cut(loan_data_extract['funded_amnt'], np.linspace(0, 35000, 8))
count_plot(['funded_amnt_bin_catlg'])
stacked_plot('funded_amnt_bin_catlg','Funded Amount vs Loan Status')

# %% [markdown]
# ### Observation
# The trend of funded Amount closely matches the loan amount. Both these values are stringly correlated.

# %% [markdown]
# #### Note
# An interesting analysis - check the trend of charged off loans when the funded amount is less than the amount applied for,<br>
# by the applicant.

# %%
# Create a flag to indicate if the funded amount is same as Applicant requested Amount
loan_data_extract['full_amnt_given'] = np.where(loan_data_extract['loan_amnt'] == loan_data_extract['funded_amnt'], True, False)
loan_data_extract['full_amnt_given'] = loan_data_extract['full_amnt_given'].apply(lambda x:'Issued Applied Amount' if x is True else 'Issued Reduced Amount')

# %%
count_plot(['full_amnt_given'])
stacked_plot('full_amnt_given','Loan Status percentage when the Issued Amount is less than Applied Amount')

# %% [markdown]
# ### Observation
# From the charts, it is evident that applications that have Funded Amount less than the customer applied amount, are marginally likely <br>
# to be charged off.

# %% [markdown]
# ## Term - Tenure of the loan - 36 Months or 60 Months

# %%
count_plot(['term'])
stacked_plot('term','Tenure of Loan vs Loan Status')

# %% [markdown]
# ### Observation
# Loans with longer tenure have high percentage of Charge Off applications. This indicates that customers who have longer <br>
# commitments opted charge off due to varying financial circumstances over the time.

# %% [markdown]
# ## Interest Rate of the loan

# %%
box_plot(['int_rate_f'])

# %%
# Bin the Interest Rates into categories and chart the plot.
loan_data_extract['int_rate_bin']=pd.cut(loan_data_extract['int_rate_f'], np.linspace(5, 25, 5))

# %%
count_plot(['int_rate_bin'])
stacked_plot('int_rate_bin','Interest rates vs Loan Status')

# %% [markdown]
# ### Observation
# In general, the higher the interest rate is, the higher is the percentage of Charged off Loans. <br>
# Loans with in interest rate 10 -15 are most frequent, followed by those with  5-10 and 15-20.<br>
# However, the percentage of chareged Offs is high in 10-15, followed by 5-10. <br>
# This analysis evidences, that there is some risk in issuing the High Interest Loans and additional due deligence is required while processing loan applications

# %% [markdown]
# ## Analyse Dti - Debit to Income Ratio

# %%
# Bin the DTI into categories and chart the plots.
loan_data_extract['dti_bin']=pd.cut(loan_data_extract['dti'], np.linspace(0, 30, 7))

# %%
box_plot(['dti'])

# %%
count_plot(['dti_bin'])
stacked_plot('dti_bin','DTI vs Loan Status')

# %% [markdown]
# ### Observation
# The percentage of charged off loans is increasing as the dti increases.<br>
# Also, from box plot, it is evident,that dti is higher in charged off loans. <br>
# While dti in 10-15 is frequent observation, the percentage of charge offs are higher in 15-20. <br>
# This evidences, that high dti meant a risky loan application.

# %% [markdown]
# ## Analyse Credit History - The difference in the issue date and earliest credit date

# %%
# Bin the calculated credit age and then chart the plot
loan_data_extract['time_delta_bin'] = pd.cut(loan_data_extract['time_delta_int'], np.linspace(2, 65, 22))

# %%
count_plot(['time_delta_bin'])
stacked_plot('time_delta_bin','Credit History in Years vs Loan Status')

# %% [markdown]
# ### Observations
# There is a mixed trend in the charged off loans when plotted against the credit age. <br>
# In general, a very low credit age meant, the financial profile of the applicant is not clear. <br>
# A high credit age meant, the financial profile of the applicant is superseded by the age of the application. <br>
# This trend is clearly visible in the above percentage stacked plot.

# %% [markdown]
# ## Analyse Home Ownership Status and its impact on Loan Status

# %%
count_plot(['home_ownership'])
stacked_plot('home_ownership','Home Ownership status vs Loan Status')

# %% [markdown]
# ### Observation
# The home ownership with 'other' are charging off the loans at higher rate. <br>
# This shows that 'other' category of the home ownership should be identified as risk. Further checks are required to understand <br>
# the residency status.

# %% [markdown]
# ## Analyse Annual Income impact on Loan Status

# %%
#Bin the Annual Income and chart the plots.
loan_data_extract['annual_inc_bin'] = pd.cut(loan_data_extract['annual_inc_log2'], np.linspace(10, 23, 5))

# %%
count_plot(['annual_inc_bin'])
stacked_plot('annual_inc_bin','Annual Income vs Loan Status')

# %% [markdown]
# ### Observation
# The general trend is, as the annual income increases, the percentage of charged off loans decreases. <br>
# This is eveident from the fact that loans in the range 16.5 - 19.75 have lower charged off percentage compared to 13.25 - 16.5 <br>
# which is highly frequent.

# %% [markdown]
# ## Analyse Year of Issue and trend of charged off loans

# %%
# Extract the year from formatted Issue date and chart the plots for analysis
loan_data_extract['issue_date_year']=loan_data_extract['issue_date_dt'].dt.year
loan_data_extract['issue_date_year']=loan_data_extract['issue_date_year'].astype(str)
count_plot(['issue_date_year'])
stacked_plot('issue_date_year','Percentage of loans changed and Defaulted across Years')

# %% [markdown]
# ### Observation
# The number of loans gradually increased from 2007 till 2011 <br>
# However, the percentage of the charge off loans issued have reduced from 2007 till 2010. <br>
# In 2011, there is high charge off rate. This could be partly due to number of loans issued. <br>
# Further analysis will be required to draw any conclusions on this behavior.

# %% [markdown]
# ### Analyse pub_rec - Number of derogatory comments on the credit file

# %%
loan_data_extract.pub_rec=loan_data_extract.pub_rec.astype(str)
count_plot(['pub_rec'])
stacked_plot('pub_rec','Number of Derogatory comments on the Credit file')

# %% [markdown]
# ### Observation
# It is evident from the above chart that, the higher the derogatory comments are, the higher is the charge off rate.

# %% [markdown]
# ### Analyse pub_rec_bankruptcies - Number of public bankruptcies on the credit file

# %%
count_plot(['pub_rec_bankruptcies'])
stacked_plot('pub_rec_bankruptcies','Public Bankruptices vs Loan Status')

# %% [markdown]
# ### Observation
# It is evident from the above chart that, the higher the bankruptcies are, the higher is the charge off rate.

# %% [markdown]
# ### Analyse Source and Income Verification

# %%
count_plot(['income_verification','source_verification'])
stacked_plot('income_verification','Income verification vs Loan status')
stacked_plot('source_verification','Source verification vs Loan status')

# %% [markdown]
# ### Observation
# In the analysis of Source Verification, apparently there is no effect on the charged off rate, even though there is stark difference in the counts.<br>
# In case of Income verification, the charge off rate is higher ,when the income has been verified.<br>
# This shows, that income verification checks have no effect in case of Risky applications. The income verification process <br>
# will need to be reviewed.

# %% [markdown]
# ### Analyse Purpose mentioned by customer on the application

# %%
count_plot(['purpose_mapped'])
stacked_plot('purpose_mapped','Loan Status trend across various purposes')

# %% [markdown]
# ### Observation
# In general, the unsecured loans - like the small business loans, followed by educational loans are highly charged off. <br>
# Debit Consolidation is the most common purpose

# %% [markdown]
# ### Analyse the employee title diclosure impact on loan status

# %%
count_plot(['emp_title_provided'])
stacked_plot('emp_title_provided','Loan Status percentages vs Disclosure of Employee name')

# %% [markdown]
# ### Observation
# Apparently, the rate of charged off applications are higher in cases, where the Employee title was not disclosed.<br>
# However, the 'Not Disclosed' is much less compared to 'Disclosed' category and that could have some bearing on this trend. <br>
# Further Analysis will be required on Employee title to draw logical conclusions.

# %% [markdown]
# ### Analyse the trend of Inquiries in past 6 months

# %%
loan_data_extract.inq_last_6mths=loan_data_extract.inq_last_6mths.astype(str)
count_plot(['inq_last_6mths'])
stacked_plot('inq_last_6mths','Number of Inquiries vs Loan Status')

# %% [markdown]
# ### Observation
# Considering both the count plot and stacked percentage plot, it is evident that, the higher the number of inquiries, the higher <br>
# is the rate of charge off.  This parameter shows the desperation of the customer for a credit line.

# %% [markdown]
# ### Analyse the Employment Length vs Loan status

# %%
loan_data_extract.emp_length=loan_data_extract.emp_length.astype(str)
count_plot(['emp_length'])
stacked_plot('emp_length','Employee Length vs Loan Status')

# %% [markdown]
# ### Observation
# There is no clear trend of employment length impact on the charged off rate. Further investigation will be required to study <br>
# this variable

# %% [markdown]
# ### Analyse the trend of Installment across the loan status

# %%
box_plot(['installment'])

# %%
#Bin the log of installements into ranges and chart the plots.
loan_data_extract['installment_bin'] = pd.cut(np.log2(loan_data_extract['installment']), np.linspace(3.5, 10.5, 8))

# %%
count_plot(['installment_bin'])
stacked_plot('installment_bin','Installement vs Loan Status')

# %% [markdown]
# ### Observation
# From both the count plot and stacked plot it is evident that as the instalment increases, the rate of charge off loans increases.<br>
# Loans with instalments in range 7.5 - 8.5 are common followed by 8.5 - 9.5 and 6.5 - 7.5. <br>
# Rate of charge off is marginally higher in 8.5 - 9.5

# %% [markdown]
# ### Analyse Open Account Ratio vs Loan Status

# %%
loan_data_extract['open_acct_ratio_bin'] = pd.cut(loan_data_extract['open_acct_ratio'], np.linspace(0, 1, 6))

# %%
count_plot(['open_acct_ratio_bin'])
stacked_plot('open_acct_ratio_bin','Open Account Ration vs Loan Status')

# %% [markdown]
# ### Observation
# From the above chart, it is evident that Bank is not issuing the loans to applicants who have higher open account ratio. <br>
# The general trend is, the higher the open account ratio is, the higher the chance of charging off loan

# %% [markdown]
# ### Analyse Revolving Balance Utilization Rate

# %%
box_plot(['revol_util'])
loan_data_extract['revol_util_bin'] = pd.cut(loan_data_extract['revol_util'], np.linspace(0, 100, 11))
count_plot(['revol_util_bin'])
stacked_plot('revol_util_bin','Revolving balance trend across Loan status')

# %% [markdown]
# ### Observation
# From the box plot and count plot, it is evident that, revolving balance utilization is higher in charged off loans. <br>
# Customers with considerable revolving balance (40 - 50) are top applicants. They are also having the high percentage of <br>
# charge off loans compared with applicants with utilization rate less than 40.<br>
# This general trend is  - the higher the revolving balance utilization rate, the higher is the chance of charging off loan.

# %% [markdown]
# ### Analyse Loan trend across the state and Zip Codes

# %%
count_plot(['state_code'],22,18)

# %%
stacked_plot('state_code','Loan Status Across States',14,8)

# %% [markdown]
# ### Observation
# As per the above state 'CA' has highest number of charged off applications. <br>
# In terms of percentages, the loans are highly charged off in the state NE,NIU and AE. <br>
# Observing the number of loans applied from each of these states, it is clear, that the number of applications are less and hence<br>
# this behavior. Excluding the above outlier behavior, the state with highest charged off percentage is NV - Nevada.

# %% [markdown]
# Analyse further on the zip codes and state codes

# %%
# take those states and zip codes, that have applciations mroe than 200. Calculate the percentage of charged off loans
temp_dataframe=loan_data_extract.groupby(by=['state_code','zip_code_str','loan_status']).count().reset_index()[['state_code','zip_code_str','loan_status','loan_amnt']]
temp_dataframe=pd.pivot_table(temp_dataframe,values='loan_amnt',index=['state_code','zip_code_str'],columns=['loan_status']).reset_index()
temp_dataframe=temp_dataframe[temp_dataframe['charged off']+temp_dataframe['fully paid'] >= 200]
temp_dataframe['charged off perc']=temp_dataframe['charged off']/(temp_dataframe['charged off']+temp_dataframe['fully paid'])*100
temp_dataframe=temp_dataframe.sort_values('charged off perc',ascending=False)
temp_dataframe.rename(columns={'loan_status':'Cumulative_Count'}, inplace=True)
temp_dataframe=temp_dataframe.reset_index().rename(columns={'index':'Counts'})
temp_dataframe
# Out:
# loan_status  Counts state_code zip_code_str  charged off  fully paid  \
# 0               476         NV          891        64.00      177.00
# 1                71         CA          917        71.00      269.00
# 2               156         FL          331        70.00      267.00
# 3               155         FL          330        51.00      198.00
# 4                79         CA          925        47.00      185.00
# 5               455         NJ          080        45.00      190.00
# 6                67         CA          913        50.00      215.00
# 7                80         CA          926        67.00      299.00
# 8                82         CA          928        34.00      168.00
# 9               499         NY          117        49.00      244.00
# 10               77         CA          923        33.00      167.00
# 11              159         FL          334        37.00      192.00
# 12               46         AZ          852        42.00      225.00
# 13               57         CA          902        36.00      193.00
# 14               96         CA          945        80.00      451.00
# 15              495         NY          113        41.00      233.00
# 16               75         CA          921        51.00      290.00
# 17               56         CA          900        64.00      381.00
# 18              445         NJ          070        65.00      389.00
# 19              686         TX          770        44.00      271.00
# 20              102         CA          951        30.00      189.00
# 21              171         GA          300        52.00      331.00
# 22              758         WA          980        29.00      188.00
# 23              494         NY          112        65.00      437.00
# 24               74         CA          920        28.00      193.00
# 25              482         NY          100        70.00      513.00
# 26              174         GA          303        26.00      191.00
# 27              486         NY          104        24.00      181.00
# 28              209         IL          606        48.00      445.00
# 29              309         MA          021        34.00      349.00
# 30              666         TX          750        30.00      326.00
# 31               93         CA          941        29.00      325.00
# 32              722         VA          201        17.00      206.00
# 33              140         DC          200        15.00      194.00
#
# loan_status  charged off perc
# 0                       26.56
# 1                       20.88
# 2                       20.77
# 3                       20.48
# 4                       20.26
# 5                       19.15
# 6                       18.87
# 7                       18.31
# 8                       16.83
# 9                       16.72
# 10                      16.50
# 11                      16.16
# 12                      15.73
# 13                      15.72
# 14                      15.07
# 15                      14.96
# 16                      14.96
# 17                      14.38
# 18                      14.32
# 19                      13.97
# 20                      13.70
# 21                      13.58
# 22                      13.36
# 23                      12.95
# 24                      12.67
# 25                      12.01
# 26                      11.98
# 27                      11.71
# 28                       9.74
# 29                       8.88
# 30                       8.43
# 31                       8.19
# 32                       7.62
# 33                       7.18

# %% [markdown]
# ### Observation
# So with in a state , based on the urban area, the percentage of the defaulted loans is varying. <br>
# For example, with in 'FL' the zip code 331 has highest percentage of the defaulters.

# %% [markdown]
# ### Analyse the observations using the variable  'delinq_2yrs'

# %%
loan_data_extract.delinq_2yrs=loan_data_extract.delinq_2yrs.astype(str)

# %%
count_plot(['delinq_2yrs'])
stacked_plot('delinq_2yrs','Trend of delinq_2yrs vs Loan status')

# %% [markdown]
# ### Observation
# In general, LC is not accepting the customers with higher count of 'delinq_2years'. <br>
# ('delinq_2years' - Denotes how many 30+ days past with the incidences of delinquency  in last 2 years) <br>
# The general trend is, as the count of variable increases, the percentage of charged off loans increases. <br>
# There is a definite chance of charging off loan when the delinq_2years is high. Additional checks are required to understand <br>
# the financial profile of the applicant in such cases.

# %% [markdown]
# ## Bivariate Analysis

# %%
#Extract charged off loans to a seperate Dataframe
loan_data_extract_chgoff=loan_data_extract[loan_data_extract['loan_status']=='charged off']

# %% [markdown]
# ### Analyse the DTI ratio and Verification Status

# %%
# Chart the plots grouping verification status and loan staus and take median of dti
fig=plt.figure(figsize=(6, 6), dpi=90, facecolor='w', edgecolor='k')
sns.set(style="darkgrid")
sns.barplot(y='dti',x='income_verification',hue='loan_status',
            palette='pastel',
            data=loan_data_extract.groupby(by=['income_verification','loan_status'])['dti'].median().reset_index())
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# #### Observation
# From the above it is clear, that in the cases, where Debt to Income ratio is high, the income_verification is not playing a role.
# In such cases, verification process should be improved to assess the application.

# %% [markdown]
# ### Check how the average DTI acorss the states

# %%
fig=plt.figure(figsize=(14,8), dpi=70, facecolor='w', edgecolor='k')
sns.set(style="ticks")
sns.set(style="whitegrid")
sns.barplot(x='state_code', y='dti',data=loan_data_extract)

# %% [markdown]
# ### Observation
# The Debit to Income ratio spread across the states. <br>
# This shows that the error is higher in the state 'NE' that has highest percentage of chanrged off loans. <br>
# The error is minimal in NV.

# %% [markdown]
# ### Analyse the relation between loan status, home ownership and  dti.

# %%
# Chart the plots grouping home owner ship and loan staus and take median of dti
fig=plt.figure(figsize=(6, 6), dpi=90, facecolor='w', edgecolor='k')
sns.set(style="darkgrid")
sns.barplot(y='dti',x='home_ownership',hue='loan_status',
            palette='pastel',
            data=loan_data_extract.groupby(by=['home_ownership','loan_status'])['dti'].median().reset_index())
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ### Observation
# If the DTI is higher and the home ownership is 'own', then the percentage of defaulting loan is higher.

# %% [markdown]
# ### Determine any correlations from the heat map

# %%
fig=plt.figure(figsize=(14, 12), dpi=50, facecolor='w', edgecolor='k')
sns.set(style="ticks", palette="pastel")
ax = sns.heatmap(loan_data_extract.corr(),annot=True)

# %% [markdown]
# ### Analyse Annual income vs interest rate impact on the Charged off loans

# %%
charged_off_income_vs_interest = pd.pivot_table(loan_data_extract_chgoff, 
                                           values='id', 
                                           index=[pd.cut(np.log10(loan_data_extract_chgoff['annual_inc']), np.linspace(3, 7, 5))], 
                                           columns=[pd.cut(loan_data_extract_chgoff['int_rate_f'], np.linspace(5, 25, 5))], 
                                           aggfunc='count', 
                                           dropna=False, 
                                           fill_value=0)

total_income_vs_interest = pd.pivot_table(loan_data_extract,
                                          values='id', 
                                           index=[pd.cut(np.log10(loan_data_extract['annual_inc']), np.linspace(3, 7, 5))], 
                                           columns=[pd.cut(loan_data_extract['int_rate_f'], np.linspace(5, 25, 5))], 
                                           aggfunc='count', 
                                           dropna=False, 
                                           fill_value=0)

charged_off_ratio_income_vs_interest = charged_off_income_vs_interest / total_income_vs_interest * 100
#charged_off_ratio_income_vs_interest.sort_index()
charged_off_ratio_income_vs_interest.plot(kind='bar')

# %% [markdown]
# ### Observation
# It is evident that -
#  - For same interest rate, charge off rate decreases with increase in annual income
#  - For same income, charge off increases with increase in interest rate

# %% [markdown]
# ## Analyse the effect of DTI and Interest Rates vs Loan status

# %%
charged_off_dti_vs_interest = pd.pivot_table(loan_data_extract_chgoff, 
                                             values='id', 
                                             index=[pd.cut(loan_data_extract_chgoff['dti'], np.linspace(0, 30, 7))], 
                                             columns=[pd.cut(loan_data_extract_chgoff['int_rate_f'], np.linspace(5, 25, 5))], 
                                             aggfunc='count', 
                                             dropna=False, 
                                             fill_value=0)

total_dti_vs_interest = pd.pivot_table(loan_data_extract, 
                                       values='id', 
                                       index=[pd.cut(loan_data_extract['dti'], np.linspace(0, 30, 7))], 
                                       columns=[pd.cut(loan_data_extract['int_rate_f'], np.linspace(5, 25, 5))], 
                                       aggfunc='count', 
                                       dropna=False, 
                                       fill_value=0)

charged_off_ratio_dti_vs_interest = charged_off_dti_vs_interest / total_dti_vs_interest * 100
#charged_off_ratio_dti_vs_interest.sort_index()
charged_off_ratio_dti_vs_interest.plot(kind='bar',figsize=(6,6))

# %% [markdown]
# ### Observation
# Apparently, for the same dti, higher interest rates result in more charge-offs<br>
# Higher interest rates have significant impact on charge offs

# %% [markdown]
# ## Annual income vs DTI

# %%
charged_off_income_vs_dti = pd.pivot_table(loan_data_extract_chgoff, 
                                        values='id', 
                                        index=[pd.cut(np.log10(loan_data_extract_chgoff['annual_inc']), np.linspace(3, 7, 5))], 
                                        columns=[pd.cut(loan_data_extract_chgoff['dti'], np.linspace(0, 30, 7))], 
                                        aggfunc='count', 
                                        dropna=False, 
                                        fill_value=0)

total_income_vs_dti = pd.pivot_table(loan_data_extract, values='id', 
                                           index=[pd.cut(np.log10(loan_data_extract['annual_inc']), np.linspace(3, 7, 5))], 
                                           columns=[pd.cut(loan_data_extract['dti'], np.linspace(0, 30, 7))], 
                                           aggfunc='count', 
                                           dropna=False, 
                                           fill_value=0)

charged_off_ratio_income_vs_dti = charged_off_income_vs_dti / total_income_vs_dti * 100
#charged_off_ratio_income_vs_dti.sort_index()
charged_off_ratio_income_vs_dti.plot(kind='bar',figsize=(6,6))

# %% [markdown]
# ### Observation
# - Charge off increases when DTI increases for same annual income
# - Charge off decrease when salary increase for same annual income

# %% [markdown]
# ### Analyse the Relationship of employment length/title Disclosure and Income Verification vs loan status

# %%
loan_data_extract['emp_length_disclosed'] = np.where(loan_data_extract['emp_length'] == 'Not Disclosed', False, True)
loan_data_extract_chgoff['emp_length_disclosed'] = np.where(loan_data_extract_chgoff['emp_length'] == 'Not Disclosed', False, True)

# %%
charged_off_rogue = pd.pivot_table(loan_data_extract_chgoff, 
                                   values='id', 
                                   index=['emp_length_disclosed','emp_title_provided'], 
                                   columns=['income_verification'], 
                                   aggfunc='count', 
                                   dropna=False, 
                                   fill_value=0)

total_rogue = pd.pivot_table(loan_data_extract, 
                             values='id', 
                             index=['emp_length_disclosed','emp_title_provided'], 
                             columns=['income_verification'], 
                             aggfunc='count', 
                             dropna=False, 
                             fill_value=0)

charged_off_rogue = charged_off_rogue / total_rogue * 100
#charged_off_rogue
charged_off_rogue.plot(kind='bar',figsize=(6,6))

# %% [markdown]
# ### Observation
#  - When employment length is disclosed and employment title is provided, charge offs are less
#  - When employment title is provided and income is verified, charge offs are less
#  - All other combination have a relatively high charge-off
#
# It is good to have employee title for income verification (self employed and own business need more scrutiny). Additionally,
# when employment title is provided employment length should be expected. This will allow a higher scrutiny.
